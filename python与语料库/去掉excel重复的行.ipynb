# %%
#https://blog.csdn.net/weixin_43474731/article/details/86629220

# %%
# 导入pandas包并重命名为pd
import pandas as pd

# 读取Excel中Sheet1中的数据
data = pd.DataFrame(pd.read_excel('学位论文.xls', 'sheet1'))

# 查看读取数据内容
print(data)

# 查看是否有重复行
re_row = data.duplicated()
print(re_row)

# 查看去除重复行的数据
no_re_row = data.drop_duplicates()
print(no_re_row)

# 查看基于[作者]列去除重复行的数据
wp = data.drop_duplicates(['作者'])
print(wp)

# 将去除重复行的数据输出到excel表中
no_re_row.to_excel("过滤重复行.xlsx")
# Out:
#                              题目  \
# 0                     汉韩同形词对比初探
# 1                     汉韩外来词对比研究
# 2              汉韩成语中植物文化意义的对比研究
# 3               汉韩基本味觉词认知语义对比研究
# 4                 汉韩谚语对比研究及教学策略
# 5    基于双语平行语料库的“V+到+NP”汉韩翻译对比研究
# 6              汉韩颜色词特征与联想意义比较研究
# 7                 汉韩含色彩词成语的比较研究
# 8                     汉韩委婉语对比研究
# 9                 汉韩现代亲属称谓语对比研究
# 10                汉韩内脏器官惯用语对比研究
# 11                   汉韩同位名词短语研究
# 12                  汉韩或然类语气副词对比
# 13                   汉韩双向语言教学解难
# 14               从韩剧汉译看汉韩称谓语用差异
# 15                   汉韩缩略词语对比研究
# 16    汉韩同义词对比及教学方案研究——以新HSK五级为例
# 17                  汉韩动词及物性对比研究
# 18                汉韩索取类动词配价对比研究
# 19                  汉韩给予类动词对比研究
# 20                 汉韩状态动词配价对比研究
# 21                汉韩“穿戴”类动词对比研究
# 22                    汉韩委婉语对比研究
# 23                   汉韩动物词语比较研究
# 24                汉韩料定类语气副词对比研究
# 25                 汉韩态度类形容词对比研究
# 26                汉韩确信类语气副词对比研究
# 27             汉韩喻人惯用语对比研究及教学方案
# ...
