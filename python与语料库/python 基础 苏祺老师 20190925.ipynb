# %%
x = 3  # 给变量赋值
x = 5
print(type(x))  #查看数据类型
x = "Peking University"  #带引号的是字符串
y = "Hello"
# Out:
# <class 'int'>

# %%
print(y + " "+ x)  # 必须加上空格
# Out:
# Hello Peking University

# %%
print(x)
# Out:
# Peking University

# %%
print(x.upper()) #调用函数，执行全大写
# Out:
# PEKING UNIVERSITY

# %%
print(x.lower()) # 调用函数，执行全小写
# Out:
# peking university

# %%
#python文本处理中大量用到，加、减、乘、除

# %%
x = """送亲友去机场时找不到停车位？到机场了却发现忘记带充电宝？登机安检时超标的神仙水不能带上飞机？旅行中有一万种可能让机场成为“人在囧途”的起点。"""

# %%
print(x)
# Out:
# 送亲友去机场时找不到停车位？到机场了却发现忘记带充电宝？登机安检时超标的神仙水不能带上飞机？旅行中有一万种可能让机场成为“人在囧途”的起点。

# %%
print(x.startswith("送"))
# Out:
# True

# %% [markdown]
# # 字符串的切片操作

# %%
x = "Peking University"

# %%
print(x[0])
print(x[1])
print(x[2])
print(x[-1]) #从后往前数
print(x[0:3]) #从0到3
# Out:
# P
# e
# k
# y
# Pek

# %%
len(x)
# Out:
# 17

# %%
print("o" in x)  #判断o是否在x里
# Out:
# False

# %%
print("ing" not in x) #判断ing是否没有在X里
# Out:
# False

# %%
## 内置函数，处理字符串

# %% [markdown]
# ## 数数操作、频次操作

# %%
len(x)
# Out:
# 17

# %%
print(x.count("e"))  # 数“e”在x里面的次数
# Out:
# 2

# %%
print(x.startswith("p")) #判断是否是p
# Out:
# False

# %%
print(x.split())  # 分开列表
# Out:
# ['Peking', 'University']

# %%
print(len(x.split(x))) #查看列表的长度
# Out:
# 2

# %%
x = '''Around 100,000 people and 70 parade floats will march before Tian'anmen Square on China's 70th birthday to showcase the nation's socioeconomic accomplishments over the decades, Zhang Ge, the executive conductor of the event, said on Wednesday.'''

# %%
print(x.split())
# Out:
# ['Around', '100,000', 'people', 'and', '70', 'parade', 'floats', 'will', 'march', 'before', "Tian'anmen", 'Square', 'on', "China's", '70th', 'birthday', 'to', 'showcase', 'the', "nation's", 'socioeconomic', 'accomplishments', 'over', 'the', 'decades,', 'Zhang', 'Ge,', 'the', 'executive', 'conductor', 'of', 'the', 'event,', 'said', 'on', 'Wednesday.']

# %%
print(len(x.split()))
# Out:
# 36

# %%
#查看语料库的句子数量

# %%
mylist = x.split(".")

# %%
print(mylist)
print(len(mylist))
# Out:
# ['送亲友去机场时找不到停车位？到机场了却发现忘记带充电宝？登机安检时超标的神仙水不能带上飞机', '旅行中有一万种可能让机场成为“人在囧途”的起点', '']
# 3

# %%
x = "送亲友去机场时找不到停车位？到机场了却发现忘记带充电宝？登机安检时超标的神仙水不能带上飞机。旅行中有一万种可能让机场成为“人在囧途”的起点。"

# %%
mylist = x.split("。")
print(mylist)
print(len(mylist))
# Out:
# ['送亲友去机场时找不到停车位？到机场了却发现忘记带充电宝？登机安检时超标的神仙水不能带上飞机。旅行中有一万种可能让机场成为“人在囧途”的起点。']
# 1

# %%
import re

x = "送亲友去机场时找不到停车位？到机场了却发现忘记带充电宝？登机安检时超标的神仙水不能带上飞机。旅行中有一万种可能让机场成为“人在囧途”的起点。"
mylist = x.split("。")
print(mylist)
print(len(mylist))
print(re.split("|。|？|",x))
# Out:
# ['送亲友去机场时找不到停车位？到机场了却发现忘记带充电宝？登机安检时超标的神仙水不能带上飞机', '旅行中有一万种可能让机场成为“人在囧途”的起点', '']
# 3
# ['', '送', '亲', '友', '去', '机', '场', '时', '找', '不', '到', '停', '车', '位', '', '', '到', '机', '场', '了', '却', '发', '现', '忘', '记', '带', '充', '电', '宝', '', '', '登', '机', '安', '检', '时', '超', '标', '的', '神', '仙', '水', '不', '能', '带', '上', '飞', '机', '', '', '旅', '行', '中', '有', '一', '万', '种', '可', '能', '让', '机', '场', '成', '为', '“', '人', '在', '囧', '途', '”', '的', '起', '点', '', '', '']

# %%
## 查看新闻的句子

# %%
import re

f = open(r"C:\Users\Geoffrey\Desktop\news.txt",encoding="utf-8" ) #打开文件
print(re.split("|。|？|",x))
# Out:
# ['', '送', '亲', '友', '去', '机', '场', '时', '找', '不', '到', '停', '车', '位', '', '', '到', '机', '场', '了', '却', '发', '现', '忘', '记', '带', '充', '电', '宝', '', '', '登', '机', '安', '检', '时', '超', '标', '的', '神', '仙', '水', '不', '能', '带', '上', '飞', '机', '', '', '旅', '行', '中', '有', '一', '万', '种', '可', '能', '让', '机', '场', '成', '为', '“', '人', '在', '囧', '途', '”', '的', '起', '点', '', '', '']

# %%
#print("python"C"Java")  #转义符号 \np
print("a\nb\nc")
print(r"a\nb\nc")
# Out:
# a
# b
# c
# a\nb\nc

# %%
f.readlines #读列表
f.read表示全读
f.readline#一句一句的读

# %%
#coding=utf-8
f = open(r'C:\Users\Geoffrey\Desktop\News.txt',encoding='ansi') ## 编码错误不是utf-8
x = f.read()

clause = re.split("？|。|,", x)
print(clause)
print(len(clause))
print(len(clause))
# Out:
# ["['送亲友去机场时找不到停车位", '到机场了却发现忘记带充电宝', '登机安检时超标的神仙水不能带上飞机', '旅行中有一万种可能让机场成为“人在囧途”的起点', "']"]
# 5
# 5

# %% [markdown]
# ## 列表与循环连接

# %%
x = [1, 2, 3]
for i in x : print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## 列表的函数，排序反转

# %%
x = [1, 2, 3]
x.sort() #排序

x.reverse()#颠倒
print(x)
# Out:
# [3, 2, 1]

# %%
# x为字符串
x = ["dog", "cat", "sheep"]
x.sort() #按照字母排序
print(x)
# Out:
# ['cat', 'dog', 'sheep']

# %%
x = ["dog", "cat", "sheep","dog","cat"]
print(set(x)) #集合
# Out:
# {'dog', 'cat', 'sheep'}

# %%
#读英文的新闻，输出这个新闻的所有词汇，生成词汇表，并按照首字母表
import collection

file = open("D:\BaiduNetdiskDownload\python和爬虫基础\pride_and_prejudice.txt", "r")
words = []
for line in file:
    for word in line.replace('\n', '').split(" "):
        words.append(word)
        print(words)
import
# Out:
#   File "<ipython-input-2-175f2d88683d>", line 10
#     import
#                   ^
# SyntaxError: invalid syntax

# %%
import re

f = open(r'C:\Users\Geoffrey\Desktop\Austen_Emma.txt') #打开文件
text = f.read() #存到text变量
#print(text)
words = re.split(" |--|\n,|\|\?|;|!.", text) #字符串用split操作变成列表存在word里面
types = set(words) #对列表去重，用set操作
y = list(types)
y.sort()
print(y)
print(len(y))

#print(types)
#print(len(types)) #强制类型转黄，转换成列表
#types.sort()

#print(len(text))
#print(set(text))
#print(re.split('.',x))

#text.sort()
# Out:
# ['', '\n', '\n"Ah', '\n"And', '\n"And,', '\n"As', '\n"Aye,', '\n"But', '\n"But,', '\n"Certainly', '\n"Charming', '\n"Dear', '\n"Don\'t', '\n"Dreadful', '\n"Great', '\n"Harriet', '\n"Harriet,', '\n"Have', '\n"He', '\n"I', '\n"Indeed', '\n"It', '\n"Jane', '\n"Let', '\n"Miss', '\n"Mr.', '\n"Much,', '\n"Must', '\n"My', '\n"Nay,', '\n"Never', '\n"No,', '\n"Not', '\n"Oh', '\n"Oh,', '\n"She', '\n"So', '\n"That', '\n"There', '\n"They', '\n"Very', '\n"Well,', '\n"What', '\n"When', '\n"Where', '\n"Yes', '\n"You', '\n"Your', '\n"absolutely', '\n"and', '\n"but', '\n"governess-trade,', '\n"is', '\n"remember', '\n"that', '\n"to', '\n"very', "\n'well,", '\nA', '\nAll', '\nAnd', '\nBehold', '\nBut', '\nCHAPTER', '\nCHARADE.\nMy', '\nEmma', "\nEmma's", '\nExtraordinary', '\nFrank', '\nGood', '\nHarriet', "\nHarriet's", '\nHe', '\nHow', '\nI', '\nIn', '\nIsabella,', '\nIt', '\nLiable', '\nLord', '\nMiss', '\nMr.', '\nMrs.', '\nOh', '\nPerhaps', '\nPoor', '\nPray', '\nShe', '\nSuch', '\nThe', '\nThey',
# ...

# %%
f = open(r'C:\Users\Geoffrey\Desktop\Austen_Emma.txt') ## 编码错误不是utf-8
x = f.read()

print(x.split("."))
print(len(x.split("."))) #查看句子数量

# clause = re.split("?|.|,", x)
# print(clause)
# print(len(clause))
# print(len(clause))
# Out:
# ['EMMA\nBY\nJANE AUSTEN\nVOLUME I\nCHAPTER I\nEmma Woodhouse, handsome, clever, and rich, with a comfortable home and\nhappy disposition, seemed to unite some of the best blessings of\nexistence; and had lived nearly twenty-one years in the world with very\nlittle to distress or vex her', "\nShe was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period", ' Her mother had\ndied too long ago for her to have more than an indistinct remembrance\nof her caresses; and her place had been supplied by an excellent woman\nas governess, who had fallen little short of a mother in affection', '\nSixteen years had Miss Taylor been in Mr', " Woodhouse's family, less as a\ngoverness than a friend, very fond of both daughters, but particularly\nof Emma", ' Between _them_ it was more the intimacy of sisters', " Even\nbefore Miss Taylor had ceased to hold the nominal office of g
# ...

# %% [markdown]
# #练习1
# 用变量存储姓名，年龄，城市信息，然后再通过变量打印输出
