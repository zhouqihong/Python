# %% [markdown]
# ![image.png](attachment:image.png)

# %%
9999,999,999
数字范围9999
1计算机原理概要1
2计算机概述2

实数在计算机中的表示
二进制数
ASCII码和字符映射
微型计算机的硬件组成

**查找和排序**

# %%
**思路一**

# %%
dict = {"zero：0","one：1","two：2","three:3","four:4","five:5","six:6","seven:7","eight:8","night:9","ten:10","eleven:11","twelve:12","thirteen:13","forteen:14","fifteen:15","sixteen:16","seventeen:17","eighteen:18","nineteen:19","twenty:20","thirty:30","forty:40","fifty:50","sixty:60","seventy:70","eighty:80","ninety:90","hundred:","thousand","million"}
#到99
sum = 0 #表示
num = 'eight'
print(dict[num])
for i in number.split():
    sum+= dict[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-25cb1a16789b> in <module>
#       3 sum = 0 #表示
#       4 num = 'eight'
# ----> 5 print(dict[num])
#       6 for i in number.split():
#       7     sum+= dict[i]
#
# TypeError: 'set' object is not subscriptable

# %%
#表达100-999
dict = 
sum = 0

numList.num.split('hunred')
dict[numList[0]] * 100 +
for i in numList
    sum += dict[i]

# %%
**思路二**

# %%
三位数
voc ={}
def cal(number):  #定义函数，参数是对应数
sum = 0
numList =number.split()
for i in numList:
    if i == "hundred":
        sum= 100
    else:
        sum += voc[i]
    return sum

number1=negative
number2="eight four thousand "84022
number3=8800
number4=801
number5=33
print(cal(number1))
print(cal(number2))
print(cal(number3))
print(cal(number4))
print(cal(number5))

# %%
#thousand

# %%
#综合版本
voc = {"zero：0","one：1","two：2","three:3","four:4","five:5","six:6","seven:7","eight:8","night:9","ten:10","eleven:11","twelve:12","thirteen:13","forteen:14","fifteen:15","sixteen:16","seventeen:17","eighteen:18","nineteen:19","twenty:20","thirty:30","forty:40","fifty:50","sixty:60","seventy:70","eighty:80","ninety:90","hundred:","thousand","million"}

def cal(number):
#sum = 0
    totalSum = 0
    neg = 1

if "negative" in number:
    neg = -1
    number = number[9:]
    
if "million" in number:
    numberSplit = numberStr.split('million')
    totalSum = cal(numberSplit[0]) * 1000000 + cal(numberSplit[1])
    number = numberSplit[i] 
    return neg*totalSum

if "thousand" in number:
    numberSplit = numberStr.split('thousand')
    totalSum = cal(numberSplit[0]) * 1000 + cal(numberSplit[1])
    return neg*totalSum
    
for i in numList:
    if i == "hundred":
        totalSum*= 100
    else:
        totalSum += voc[i]
    return totalSum*neg 

number1=negative
number2="eight four thousand"84022
number3=8800
number4=801
number5=33
print(cal(number1))
print(cal(number2))
print(cal(number3))
print(cal(number4))
print(cal(number5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f27bcbf8cbb1> in <module>
#       7     neg = 1
#       8
# ----> 9 if "negative" in number:
#      10     neg = -1
#      11     number = number[9:]
#
# NameError: name 'number' is not defined

# %%
#million

# %%
#negative

voc ={}
def cal(number):
sum = 0
totalSum=0
if "negative" in number:
    neg = -1
    number = number[9:]

if "million" in number:
numberSplit = numberStr.split('thousand')
totalSum = cal(numberSplit[0])*1000000
number = numberSplit[1]
    
for i in numList:
    if i == "hundred":
        sum= 100
    else:
        sum += voc[i]
    return sum

# %%
voc ={}
def cal(number):
sum = 0
totalSum=0
if "negative" in number:
    neg = -1
    number = number[9:]

if "million" in number:
numberSplit = numberStr.split('thousand')
totalSum = cal(numberSplit[0])*1000000
number = numberSplit[1]
    
for i in numList:
    if i == "hundred":
        sum= 100
    else:
        sum += voc[i]
    return sum

# %% [markdown]
# **程序示例一**

# %%
voc = {'zero':0, 'one':1, 'two':2, 'three':3, 'four': 4, 'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine':9, 'ten':10, 'eleven':11, 'twelve':12, 'thirteen':13, 'fourteen':14, 'fifteen':15, 'sixteen':16, 'seventeen':17, 'eighteen':18, 'nineteen':19, 'twenty':20, 'thirty':30,'forty':40, 'fifty':50, 'sixty':60, 'seventy':70, 'eighty':80, 'ninety':90}

def cal(numberStr):

    neg = 1
    sum = 0
    hudSum = 0
    
    if "negative" in numberStr:
        numberStr = numberStr[9:] #只看negative之后的字符串
        neg = -1
    
    if "million" in numberStr:
        numberSplit = numberStr.split("million")
        sum += cal(numberSplit[0]) * 1000000
        numberStr = numberSplit[1]
        
    if "thousand" in numberStr:
        numberSplit = numberStr.split("thousand")
        sum += cal(numberSplit[0]) * 1000
        numberStr = numberSplit[1]

    numberList = numberStr.split()         
    for i in numberList:
        if i == "hundred":
            hudSum *= 100
        else:
            hudSum += voc[i]

    return neg * (sum + hudSum)
        
number = input()
print(cal(number))

# %% [markdown]
# **程序二**

# %%
voc = {'zero':0, 'one':1, 'two':2, 'three':3, 'four': 4, 'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine':9, 'ten':10, 'eleven':11, 'twelve':12, 'thirteen':13, 'fourteen':14, 'fifteen':15, 'sixteen':16, 'seventeen':17, 'eighteen':18, 'nineteen':19, 'twenty':20, 'thirty':30,'forty':40, 'fifty':50, 'sixty':60, 'seventy':70, 'eighty':80, 'ninety':90}

def cal(numberStr):

    neg = 1
    sum = 0
    
    if "negative" in numberStr:
        numberStr = numberStr[9:]
        neg = -1
    
    if "million" in numberStr:
        numberSplit = numberStr.split("million")
        sum = cal(numberSplit[0]) * 1000000 + cal(numberSplit[1])
        return neg * sum
        
    if "thousand" in numberStr:
        numberSplit = numberStr.split("thousand")
        sum = cal(numberSplit[0]) * 1000 + cal(numberSplit[1])
        return neg * sum

    numberList = numberStr.split()         
    for i in numberList:
        if i == "hundred":
            sum *= 100
        else:
            sum += voc[i]

    return neg * sum
        
number = input()
print(cal(number))

# %% [markdown]
# **程序三**

# %%
voc = {'zero':0, 'one':1, 'two':2, 'three':3, 'four': 4, 'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine':9, 'ten':10, 'eleven':11, 'twelve':12, 'thirteen':13, 'fourteen':14, 'fifteen':15, 'sixteen':16, 'seventeen':17, 'eighteen':18, 'nineteen':19, 'twenty':20, 'thirty':30,'forty':40, 'fifty':50, 'sixty':60, 'seventy':70, 'eighty':80, 'ninety':90}

def cal(numberStr):

    sum = 0
    neg = 1
    cur = 0
    
    numberList = numberStr.split()         
    for i in numberList:
        if i == "negative":
            neg = -1
        elif i == "million":
            sum += cur * 1000000
            cur = 0
        elif i == "thousand":
            sum += cur *1000
            cur = 0 
        elif i == "hundred":
            cur *= 100
        else:
            cur += voc[i]

    return neg * (sum + cur)
        
number = input()
print(cal(number))
# Out:
# two thousand one hundren
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-74b3f99808ca> in <module>
#      25
#      26 number = input()
# ---> 27 print(cal(number))
#
# <ipython-input-1-74b3f99808ca> in cal(numberStr)
#      20             cur *= 100
#      21         else:
# ---> 22             cur += voc[i]
#      23
#      24     return neg * (sum + cur)
#
# KeyError: 'hundren'

# %%
#精简版

if
else

# %%
Q1四位数的四则运算
Q2一位数的二则运算

# %%
#自动生成目录
1点击word标题 生成标题，在导航栏中看到文章结构
2根据标题自动生成目录

# %% [markdown]
# # python处理word文档

# %% [markdown]
# 1安装
#
# pip install python-docx

# %% [markdown]
# 2.导入
#
# import docx

# %% [markdown]
# 3.对word结构的认识
# 1).word的两种文档格式等级
#     块等级-段落、图片、表格、标题、列表
#     内联等级-字符
#
# 2).对象的概念
# 对象（object）：具有属性和方法的事物
#
# 对象.属性  可以获取或赋值
# 对象.方法()  对该对象能够执行的操作/函数

# %%
#画海龟
import turtle
turtle.color('purple')
for i in range(50):
    turtle.forward(300) #前进
    turtle.right(142) #右转

# %%
import docx

myDoc=docx.Document() #
print(myDoc)

myDoc.save("hellow,world") #

# %%
import docx

myDoc = docx.Document('demo.docx')
len(doc.paragrans)

doc.paragraph[0].text  #paragraph对象的text属性
doc.paragraph[1].run[0].text
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# <ipython-input-4-d7cc91d91d86> in <module>
#       1 import docx
#       2
# ----> 3 myDoc = docx.Document('demo.docx')
#       4 len(doc.paragrans)
#
# C:\ProgramData\Anaconda3\lib\site-packages\docx\api.py in Document(docx)
#      23     """
#      24     docx = _default_docx_path() if docx is None else docx
# ---> 25     document_part = Package.open(docx).main_document_part
#      26     if document_part.content_type != CT.WML_DOCUMENT_MAIN:
#      27         tmpl = "file '%s' is not a Word file, content type is '%s'"
#
# C:\ProgramData\Anaconda3\lib\site-packages\docx\opc\package.py in open(cls, pkg_file)
#     126         *pkg_file*.
#     127         """
# --> 128         pkg_reader = PackageReader.from_file(pkg_file)
#     129         package = cls()
# ...

# %%
读取整个文档内容，不考虑样式

def getText(fileName):
    doc = docx.Document(fileName)
    fullText=[]
    
def p in doc.paragrph:
    fullText.append(p.text)

return'\n'.join(fullText)

# %%
添加图片
添加
作业
