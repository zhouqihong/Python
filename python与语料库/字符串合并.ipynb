# %%
str1 = """
留学生
本文
写作
例如
语块
交际
字句
效应
流利
感知
探讨
论文
层面
停顿
华裔
维度
模型
评分
结果显示
华人
显性
后测
篇章
复杂性
义项
测验
情景
如例
实证
路径
长度
结式
复杂度
视角
隐性
语句
高校
述题
方差分析
题目
得分
学科
模态
显著性
时长
激活
中高级
前测
小句
事物
场景
辨析
凸显
会话
肯定
信度
年代
实验组
量表
国语
所谓
来华
论元
字料
为例
分数
语者
标准差
吕叔湘
建构
效度
情态
含意
反思
声学
名名
存现
排序
作者简介
学期
无声
匹配
超纲词
低音
复现
教学策略
情状
丰富性
解读
评测
中文系
题型
可是
聚焦
识字
标点
操练
移位
交互作用
联想
因变量
重置
听说
重要性
做法
趣味性
全球
用词
体验
对照组
口音
系数
自变量
平均值
比率
相关性
高水平

"""
b = '' .join(str1) 
b
# Out:
# '\n留学生\n本文\n写作\n例如\n语块\n交际\n字句\n效应\n流利\n感知\n探讨\n论文\n层面\n停顿\n华裔\n维度\n模型\n评分\n结果显示\n华人\n显性\n后测\n篇章\n复杂性\n义项\n测验\n情景\n如例\n实证\n路径\n长度\n结式\n复杂度\n视角\n隐性\n语句\n高校\n述题\n方差分析\n题目\n得分\n学科\n模态\n显著性\n时长\n激活\n中高级\n前测\n小句\n事物\n场景\n辨析\n凸显\n会话\n肯定\n信度\n年代\n实验组\n量表\n国语\n所谓\n来华\n论元\n字料\n为例\n分数\n语者\n标准差\n吕叔湘\n建构\n效度\n情态\n含意\n反思\n声学\n名名\n存现\n排序\n作者简介\n学期\n无声\n匹配\n超纲词\n低音\n复现\n教学策略\n情状\n丰富性\n解读\n评测\n中文系\n题型\n可是\n聚焦\n识字\n标点\n操练\n移位\n交互作用\n联想\n因变量\n重置\n听说\n重要性\n做法\n趣味性\n全球\n用词\n体验\n对照组\n口音\n系数\n自变量\n平均值\n比率\n相关性\n高水平\n\n'

# %%
def replaceSpace(s):
    s = s.replace("\n", "、")
    return s
replaceSpace(b)
# Out:
# '、留学生、本文、写作、例如、语块、交际、字句、效应、流利、感知、探讨、论文、层面、停顿、华裔、维度、模型、评分、结果显示、华人、显性、后测、篇章、复杂性、义项、测验、情景、如例、实证、路径、长度、结式、复杂度、视角、隐性、语句、高校、述题、方差分析、题目、得分、学科、模态、显著性、时长、激活、中高级、前测、小句、事物、场景、辨析、凸显、会话、肯定、信度、年代、实验组、量表、国语、所谓、来华、论元、字料、为例、分数、语者、标准差、吕叔湘、建构、效度、情态、含意、反思、声学、名名、存现、排序、作者简介、学期、无声、匹配、超纲词、低音、复现、教学策略、情状、丰富性、解读、评测、中文系、题型、可是、聚焦、识字、标点、操练、移位、交互作用、联想、因变量、重置、听说、重要性、做法、趣味性、全球、用词、体验、对照组、口音、系数、自变量、平均值、比率、相关性、高水平、、'

# %%
str2 = """显著
英语
所以
还是
比如
说话
认同
呈现
此外
几乎
在于
有些
可见
其次
信念
出来
两类
已有
后者
所示
东南亚
允准
看出
速度
二是
师生
如表
见表
看法
风格
当代
大学生
一方面
感谢
提到
沉浸
同伴
均值
大多
内在
色彩
一类
猜测
融入
职前
朱德熙
所说
那些
演讲
大致
是从
近年来
提要
一项
充当
总之
相结合
看作
"""
c = ''.join(str2)
c
# Out:
# '显著\n英语\n所以\n还是\n比如\n说话\n认同\n呈现\n此外\n几乎\n在于\n有些\n可见\n其次\n信念\n出来\n两类\n已有\n后者\n所示\n东南亚\n允准\n看出\n速度\n二是\n师生\n如表\n见表\n看法\n风格\n当代\n大学生\n一方面\n感谢\n提到\n沉浸\n同伴\n均值\n大多\n内在\n色彩\n一类\n猜测\n融入\n职前\n朱德熙\n所说\n那些\n演讲\n大致\n是从\n近年来\n提要\n一项\n充当\n总之\n相结合\n看作\n'

# %%
replaceSpace(c)
# Out:
# '显著、英语、所以、还是、比如、说话、认同、呈现、此外、几乎、在于、有些、可见、其次、信念、出来、两类、已有、后者、所示、东南亚、允准、看出、速度、二是、师生、如表、见表、看法、风格、当代、大学生、一方面、感谢、提到、沉浸、同伴、均值、大多、内在、色彩、一类、猜测、融入、职前、朱德熙、所说、那些、演讲、大致、是从、近年来、提要、一项、充当、总之、相结合、看作、'

# %%
str3 = """应该
这样
很多
美国
老师
另外
往往
孔子
只是
较大
尤其
人们
例中
两组
三种
下面
不过
不会
马来西亚
更好
觉得
最大
尽管
不够
看到
新加坡
一直
是因为
等等
为什么
一次
到底
以往
日语
同学
故事
哪些
其实
值得
真正
使得
商务印书馆
德语
越来越
两者
前面
尝试
多个
另一方面
显然
后面
展开
给出
进而
泰语
用来
孩子
大家
并未
这类
一下
东西
不用
印尼
如此
意味着
陆俭明
刘颂浩
差距
最为
北京大学
有着
"""
d = ''.join(str3)
d
# Out:
# '应该\n这样\n很多\n美国\n老师\n另外\n往往\n孔子\n只是\n较大\n尤其\n人们\n例中\n两组\n三种\n下面\n不过\n不会\n马来西亚\n更好\n觉得\n最大\n尽管\n不够\n看到\n新加坡\n一直\n是因为\n等等\n为什么\n一次\n到底\n以往\n日语\n同学\n故事\n哪些\n其实\n值得\n真正\n使得\n商务印书馆\n德语\n越来越\n两者\n前面\n尝试\n多个\n另一方面\n显然\n后面\n展开\n给出\n进而\n泰语\n用来\n孩子\n大家\n并未\n这类\n一下\n东西\n不用\n印尼\n如此\n意味着\n陆俭明\n刘颂浩\n差距\n最为\n北京大学\n有着\n'

# %%
replaceSpace(d)
# Out:
# '应该、这样、很多、美国、老师、另外、往往、孔子、只是、较大、尤其、人们、例中、两组、三种、下面、不过、不会、马来西亚、更好、觉得、最大、尽管、不够、看到、新加坡、一直、是因为、等等、为什么、一次、到底、以往、日语、同学、故事、哪些、其实、值得、真正、使得、商务印书馆、德语、越来越、两者、前面、尝试、多个、另一方面、显然、后面、展开、给出、进而、泰语、用来、孩子、大家、并未、这类、一下、东西、不用、印尼、如此、意味着、陆俭明、刘颂浩、差距、最为、北京大学、有着、'

# %%
str4 = """我们
第期
就是
不是
什么
两种
三个
来说
来看
韩语
那么
日本
一样
泰国
四个
怎么
似乎
一是
几个
喜欢
这是
不少
也就是说
常常
的话
对二语
很少
听话
上海
中有
欧美
表表
衣服
越南
不好
施春宏
"""
e = ''.join(str4)
e
# Out:
# '我们\n第期\n就是\n不是\n什么\n两种\n三个\n来说\n来看\n韩语\n那么\n日本\n一样\n泰国\n四个\n怎么\n似乎\n一是\n几个\n喜欢\n这是\n不少\n也就是说\n常常\n的话\n对二语\n很少\n听话\n上海\n中有\n欧美\n表表\n衣服\n越南\n不好\n施春宏\n'

# %%
replaceSpace(e)
# Out:
# '我们、第期、就是、不是、什么、两种、三个、来说、来看、韩语、那么、日本、一样、泰国、四个、怎么、似乎、一是、几个、喜欢、这是、不少、也就是说、常常、的话、对二语、很少、听话、上海、中有、欧美、表表、衣服、越南、不好、施春宏、'

# %%
str5 = """
两个
一种
一些
韩国
这一
这里
很大
那个
"""
f = ''.join(str5)
f
# Out:
# '\n两个\n一种\n一些\n韩国\n这一\n这里\n很大\n那个\n'

# %%
replaceSpace(f)
# Out:
# '、两个、一种、一些、韩国、这一、这里、很大、那个、'

# %%
import pandas as pd
data_1 = pd.read_excel(r'D:\NLP\project_1\data\HSK5000.xlsx')
data_2 = pd.read_excel(r'D:\NLP\project_1\data\academic500.xlsx')
data_1.head()
# Out:
#    lie
# 0   爱
# 1   八
# 2  爸爸
# 3  杯子
# 4   北京

# %%
data_2.head()
# Out:
#    lie
# 0   汉语
# 1  学习者
# 2   词汇
# 3   我们
# 4   母语

# %%
words_1 = set((data_1['lie'])[:5000])
len(words_1)
# Out:
# 4999

# %%
words_2 = set((data_2['lie'])[:500])
len(words_2)
# Out:
# 500

# %%
words_set_1 = words_1 - words_2    # 只属于汉语教学的词语
words_set_2 = words_2 - words_1    # 只属于六级词汇的词语
common_words = words_1 & words_2   # 共有的词语

# %%
print('只属于汉语教学的词语的个数：{}'.format(len(words_set_1)))
print('只属于六级词汇的词语的个数：{}'.format(len(words_set_2)))
print('共有的词语的个数：{}'.format(len(common_words)))
# Out:
# 只属于汉语教学的词语的个数：4925
# 只属于六级词汇的词语的个数：426
# 共有的词语的个数：74

# %%
words_set_2
# Out:
# {'一下',
#  '一些',
#  '一方面',
#  '一是',
#  '一次',
#  '一种',
#  '一类',
#  '一项',
#  '三个',
#  '三种',
#  '上海',
#  '下面',
#  '不会',
#  '不够',
#  '不好',
#  '不少',
#  '不是',
#  '不用',
#  '东南亚',
#  '两个',
#  '两种',
#  '两类',
#  '两组',
#  '两者',
#  '中心语',
#  '中文系',
#  '中有',
#  '中高级',
#  '丰富性',
#  '为例',
#  '主编',
#  '主观',
#  '主语',
#  '主谓',
#  '义类',
#  '义项',
#  '也就是说',
#  '习得',
#  '书面语',
#  '事物',
#  '二是',
#  '二语',
#  '二语者',
#  '互动',
#  '交互作用',
#  '交际',
#  '人们',
#  '什么',
#  '介词',
#  '代词',
#  '会话',
#  '似乎',
#  '低音',
#  '作者简介',
#  '使得',
#  '例中',
#  '例句',
#  '例子',
#  '信度',
#  '俭明',
#  '修辞',
#  '修饰',
#  '偏误',
#  '做法',
#  '停顿',
#  '允准',
#  '元音',
#  '全球',
#  '共现',
#  '关键词',
#  '几个',
#  '凸显',
#  '出来',
#  '出版社',
#  '分句',
#  '分数',
#  '分班',
#  '刘颂浩',
#  '初中级',
#  '初级阶段',
#  '前人',
#  '前测',
#  '前者',
#  '前面',
#  '副词',
#  '动宾',
#  '动词',
#  '动量',
#  '助词',
#  '北京大学',
#  '匹配',
#  '华人',
#  '华文',
#  '华裔',
#  '华语',
#  '印尼',
#  '原文',
#  '参考文献',
#  '及物动词',
#  '发音',
#  '受试者',
#  '变量',
#  '叙述',
#  '口试',
#  '口语',
#  '句型',
#  '句式',
#  '句末',
# ...

# %%
words_set_1
# Out:
# {'沉重',
#  '振奋',
#  '种族',
#  '辆',
#  '法院        ',
#  '阻碍',
#  '规模        ',
#  '抓紧        ',
#  '输',
#  '显然        ',
#  '莫名其妙',
#  '火',
#  '履行',
#  '智慧        ',
#  '接待        ',
#  '说不定      ',
#  '区别',
#  '水利',
#  '担任        ',
#  '目标',
#  '角',
#  '登机牌      ',
#  '沉闷',
#  '雷        ',
#  '近代        ',
#  '马上',
#  '不但',
#  '哈          ',
#  '件 ',
#  '不得不',
#  '以',
#  '森林',
#  '叮嘱',
#  '策划',
#  '谋求',
#  '历代',
#  '痛苦        ',
#  '迎接        ',
#  '拼命',
#  '办法',
#  '漫长',
#  '陈旧',
#  '巧妙        ',
#  '本身',
#  '岛屿',
#  '偶然        ',
#  '味道',
#  '盖          ',
#  '玩 ',
#  '一旦        ',
#  '调节',
#  '开 ',
#  '扛',
#  '气味',
#  '到达        ',
#  '胆小鬼          ',
#  '一共',
#  '讨厌',
#  '混淆',
#  '寒暄',
#  '打工        ',
#  '注视',
#  '饱经沧桑',
#  '担保',
#  '敌视',
#  '温带',
#  '踩          ',
#  '尽量        ',
#  '事先        ',
#  '确立',
#  '丘陵',
#  '收据        ',
#  '掠夺',
#  '违背',
#  '年代        ',
#  '灭亡',
#  '抄          ',
#  '主观        ',
#  '公里',
#  '嫌',
#  '孙子',
#  '遇到',
#  '舱',
#  '码头',
#  '合作        ',
# ...

# %%
common_words
# Out:
# {'一样',
#  '一直',
#  '不过',
#  '东西',
#  '为什么',
#  '主题',
#  '以往',
#  '体验',
#  '作文',
#  '例如',
#  '信念',
#  '借鉴',
#  '值得',
#  '假设',
#  '充当',
#  '其实',
#  '其次',
#  '内在',
#  '写作',
#  '几乎',
#  '到底',
#  '反思',
#  '口音',
#  '句子',
#  '另外',
#  '可是',
#  '呈现',
#  '大家',
#  '大致',
#  '定义',
#  '对立',
#  '尝试',
#  '尤其',
#  '尽管',
#  '差距',
#  '应该',
#  '归纳',
#  '往往',
#  '思维',
#  '总之',
#  '意味着',
#  '感谢',
#  '探讨',
#  '推测',
#  '推理',
#  '搭配',
#  '操练',
#  '故事',
#  '教授',
#  '文献',
#  '方言',
#  '显著',
#  '朗读',
#  '框架',
#  '模型',
#  '母语',
#  '流利',
#  '演讲',
#  '看法',
#  '真正',
#  '研究生',
#  '联想',
#  '肯定',
#  '色彩',
#  '范畴',
#  '被动',
#  '要素',
#  '词典',
#  '词汇',
#  '词语',
#  '语法',
#  '还是',
#  '进而',
#  '速度'}

# %%
data_3 = pd.read_excel(r'D:\NLP\project_1\data\academic209.xlsx')
data_3.head()
# Out:
#    lie
# 0  留学生
# 1   本文
# 2   写作
# 3   例如
# 4   语块

# %%
words_3 = set((data_3['lie'])[:209])
len(words_3)
# Out:
# 117

# %%
common_word1 = common_words - words_3
common_word1
len(common_word1)
# Out:
# 62

# %%
def replaceSpace(s):
    s = s.replace("\n", "、")
    return s
replaceSpace(common_words)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-05fccbd5006a> in <module>
#       2     s = s.replace("\n", "、")
#       3     return s
# ----> 4 replaceSpace(common_words)
#
# <ipython-input-84-05fccbd5006a> in replaceSpace(s)
#       1 def replaceSpace(s):
# ----> 2     s = s.replace("\n", "、")
#       3     return s
#       4 replaceSpace(common_words)
#
# AttributeError: 'set' object has no attribute 'replace'

# %%
with open('只属于汉语教学的词语.txt','w') as f:
    for word in words_set_1:
        f.write(word +'\n')
        
with open('只属于六级词汇的词语.txt','w') as f:
    for word in words_set_2:
        f.write(word +'\n')
        
with open('共有的词语.txt','w') as f:
    for word in common_words:
        f.write(word + '\n')

# %%
data_1 = data_1.dropna(axis=0,how='any')
words_1 = set(list(data_1['A'])[:5000])
len(words_1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-13c4d9a490b9> in <module>
# ...

# %%
#coding = utf-8
f1 = open(r'D:\NLP\project_1\data\academic500.txt',encoding='ansi') 
str1 = f1.read()
f2 = open(r'D:\NLP\project_1\data\HSK5000.txt',encoding='ansi')
str2 = f2.read()

# %%
lprint(str1,str2)
# Out:
# 汉语
# 学习者
# 词汇
# 我们
# 母语
# 语法
# 习得
# 动词
# 二语
# 语义
# 显著
# 词语
# 汉字
# 语素
# 口语
# 第期
# 英语
# 语料
# 构式
# 留学生
# 话题
# 两个
# 句子
# 偏误
# 句法
# 本文
# 对外汉语
# 被试
# 写作
# 认知
# 语境
# 例如
# 语块
# 交际
# 字句
# 一种
# 一些
# 华文
# 第二语言
# 短语
# 宾语
# 华语
# 就是
# 语料库
# 应该
# 语用
# 不是
# 主语
# 这样
# 句式
# 词义
# 什么
# 韵律
# 对比
# 发音
# 韩国
# 语言学
# 这一
# 所以
# 语体
# 两种
# 效应
# 三个
# 还是
# 作文
# 教学模式
# 生词
# 来说
# 量词
# 音节
# 角度
# 范畴
# 用法
# 话语
# 流利
# 来看
# 副词
# 补语
# 学者
# 比如
# 教学法
# 感知
# 朗读
# 方言
# 现代汉语
# 很多
# 探讨
# 语篇
# 常用
# 互动
# 重音
# 书面语
# 说话
# 美国
# 论文
# 外语
# 层面
# 认同
# 韩语
# 呈现
# 那么
# 词汇量
# 停顿
# 搭配
# 教授
# 研究者
# 词表
# 华裔
# 维度
# 老师
# 变量
# 模型
# 谓语
# 另外
# 声调
# 音高
# 往往
# 强调
# 框架
# 评分
# 词典
# 孔子
# 结果显示
# 此外
# 语调
# 华人
# 几乎
# 课文
# 正确率
# 显性
# 介词
# 复合词
# 假设
# 动量
# 只是
# 后测
# 词类
# 篇章
# 观点
# 图式
# 修辞
# 例句
# 课堂教学
# 复杂性
# 较大
# 义项
# 在于
# 有些
# 关键词
# 这里
# 日本
# 测验
# 复句
# 元音
# 尤其
# 可见
# 情景
# 近义词
# 省略
# 如例
# 定语
# 形容词
# 人们
# 主观
# 主题
# 实证
# 路径
# 长度
# 学界
# 结式
# 例中
# 复杂度
# 视角
# 纠错
# 访谈
# 其次
# 隐性
# 文献
# 一样
# 信念
# 语句
# 高校
# 出来
# 泰国
# 述题
# 要素
# 两组
# 四个
# 二语者
# 方差分析
# 状语
# 怎么
# 两类
# 题目
# ...

# %%
listr1 = []
for substrr1 in str1:
    if substrr1 not in str2:
        listr1.append(substrr1)
print(listr1)
# Out:
# ['韵', '韩', '韩', '吕', '湘', '祈', '朱', '熙', '尼', '刘', '浩']
