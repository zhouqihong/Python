# %% [markdown]
# ## 第五章 绘图模块

# %% [markdown]
# 本章主要介绍Python中的绘图模块：Matplotlib的使用。mat=matlab人类受限于思维能力理解数据的方法及其有限，一部分是通过数字特征一部分是结合商业业务知识。那么把这两者完美的结合起来的方式就是通过探索性数据分析,这也是数据学科中针对商业数据分析最重要的一步。探索性数据分析其实是试图通过数字特征与数据可视化的方式结合业务知识展示数据。在Python中这个功能将会通过Matplotlib模块来实现。

# %% [markdown]
# ## 第一节 基本绘图
#
# - 线图
# - 散点图
# - legend

# %%
import matplotlib.pyplot as plt ## 画图必备
import numpy as np
import pandas as pd

# %% [markdown]
# 第一幅图

# %%
x = np.linspace(0, 2, 100) #从0开始到2，一共取100个等差数列

plt.figure(1)  #画第一张图
plt.plot(x, x, label='linear')
plt.figure(2) #画第二张图
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label') #x轴，可以自己命名
plt.ylabel('y label')

plt.title("Simple Plot") #题目

plt.legend() #图例，比例

plt.show()

# %% [markdown]
# 画什么样的图？点图还是线图？什么样的点？什么样的线？怎样控制这些参数？

# %% [markdown]
# 简单作图法

# %%
fig = plt.figure()  # an empty figure with no axes
fig.suptitle('No axes on this figure')  # Add a title so we know which it is,fig.suptitle画子图
plt.show()

# %%
fig, ax_lst = plt.subplots(2,2)  # a figure with a 2x2 grid of Axes

# %% [markdown]
# 再看一种code风格

# %%
x = np.arange(0, 10, 0.2) #从0到10，间隔是0.2
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y) #在ax上面，画到当前的fiture,指定横轴和纵轴
plt.show()

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
t = np.arange(0., 5., 0.2) #从0开始，到5，间隔2

# red dashes, blue squares and green triangles
#plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.plot(t, t, t, t**2, t, t**3)
plt.show()

# %%
t = np.arange(0., 5., 0.2) #从0开始，到5，间隔2

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^') #r=read, g^=green的三角形,bs=blue的squr形状，
plt.plot(t, t, t, t**2, t, t**3)
plt.show()

# %%
# ?plt.plot

# %%
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, t, t**3, 'g^') ## 默认是'b-':blue line
plt.show()

# %% [markdown]
# 图中点线的更多特征

# %%
plt.scatter(t,t**2) #画散点图

# %%
plt.scatter(t,t**2,c=t,s=t*20) #s表示size,t*20表示点的大小

# %%
X = pd.read_csv('./sk600848.csv')

# %%
X.head()
# Out:
#          date   open   high  close    low     volume  price_change  p_change  \
# 0  2019-09-25  27.28  27.29  26.60  26.53   67050.33         -0.73     -2.67
# 1  2019-09-24  27.67  27.80  27.33  27.31   66308.66         -0.31     -1.12
# 2  2019-09-23  28.00  28.19  27.64  27.50   76006.28         -0.65     -2.30
# 3  2019-09-20  27.96  28.88  28.29  27.67  125565.73          0.49      1.76
# 4  2019-09-19  27.83  28.02  27.80  27.47   77383.31          0.04      0.14
#
#       ma5    ma10    ma20      v_ma5    v_ma10     v_ma20
# 0  27.532  27.563  27.482   82462.86  87380.27  100317.19
# 1  27.764  27.667  27.512   89855.82  88897.67  102737.68
# 2  27.814  27.712  27.489   98391.88  92873.16  105143.73
# 3  27.820  27.680  27.496  100271.05  93751.82  109555.71
# 4  27.672  27.593  27.493   94281.90  96297.90  113326.60

# %%
plt.plot('open','close','bo',data = X)

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50), #从0到50，选50个整数，c控制color
        'd': np.random.randn(50)} #d控制size
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

#构建字典

# %% [markdown]
# X 轴可以是分类变量

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=[9,3]) ## 注意这个参数 9代表宽，3代表高

plt.subplot(131) #1行3列的第一幅图
plt.bar(names, values)
plt.subplot(132) #1行3列的第二幅图
plt.scatter(names, values)
plt.subplot(133) #1行3列的第三幅图
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# plot 调用的一般格式：
#
# plot([x], y, [fmt], *, data=None, * * kwargs)
#
# plot([x], y, [fmt], [x2], y2, [fmt2], ..., * * kwargs)

# %%
plt.plot(x, y)        # plot x and y using default line style and color
plt.plot(x, y, 'bo')  # plot x and y using blue circle markers ,bo表示blue的小圆圈0
plt.plot(y)           # plot y using x as index array 0..N-1
plt.plot(y, 'r+')     # with red plusses r+ 表示用红色的加号

# %%
x=np.linspace(0,1,20)

# %%
y
# Out:
# array([ 0.        ,  0.19866933,  0.38941834,  0.56464247,  0.71735609,
#         0.84147098,  0.93203909,  0.98544973,  0.9995736 ,  0.97384763,
#         0.90929743,  0.8084964 ,  0.67546318,  0.51550137,  0.33498815,
#         0.14112001, -0.05837414, -0.2555411 , -0.44252044, -0.61185789,
#        -0.7568025 , -0.87157577, -0.95160207, -0.993691  , -0.99616461,
#        -0.95892427, -0.88345466, -0.77276449, -0.63126664, -0.46460218,
#        -0.2794155 , -0.0830894 ,  0.1165492 ,  0.31154136,  0.49411335,
#         0.6569866 ,  0.79366786,  0.8987081 ,  0.96791967,  0.99854335,
#         0.98935825,  0.94073056,  0.85459891,  0.7343971 ,  0.58491719,
#         0.41211849,  0.22288991,  0.02477543, -0.17432678, -0.36647913])

# %%
x
# Out:
# array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#        0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#        0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#        0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ])

# %%
y = x**2

# %%
plt.plot(y,'r+')  #'r+'表示红色的+， 可以替换成‘bo’

# %%
plt.plot(x, y, 'go--', linewidth=2, markersize=5) # markersize5也可以替换,g0--表示green蓝色的圆和线条

# %%
plt.plot(x, y, color='green', marker='D', linestyle='dashed', #D表示菱形dimond
     linewidth=2, markersize=12)

# %%
# ?plt.plot

# %% [markdown]
# 画多个图形

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
 
t1 = np.arange(0.0, 5.0, 0.1) #从0到5，每隔0.1画个点
t2 = np.arange(0.0, 5.0, 0.02)#从0到5，每隔0.02画个点

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k') #k表示black，k是最后一个字母

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

# %% [markdown]
# 在图片上添加文本
# - plt.xlabel
# - plt.ylabel
# - plt.title
# - plt.text

# %%
mu, sigma = 100, 15 #均值为100
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')  ## 在x轴添加文本
plt.ylabel('Probability')  ## 在y轴添加文本
plt.title('Histogram of IQ') ## 添加标题
plt.text(60, .025, r'$\mu=100,\ \sigma=15$') ## 在（60，0.025）坐标处添加文本, 同时注意公式的使用 r是必须的,，r有意义表示原始符号
plt.axis([40, 160, 0, 0.03])
plt.grid(True) #表示网格，不加表示去掉
plt.show()

# %% [markdown]
# ## 第二节 绘图进阶
# - 画图的全过程
# - 从数据开始
# - 开始画图
# - 中间修改
# - 最后存储

# %% [markdown]
# Data： 一些公司的销售额

# %%
# sphinx_gallery_thumbnail_number = 10
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

data = {'Barton LLC': 109438.50,
        'Frami, Hills and Schmidt': 103569.59,
        'Fritsch, Russel and Anderson': 112214.71,
        'Jerde-Hilpert': 112591.43,
        'Keeling LLC': 100934.30,
        'Koepp Ltd': 103660.54,
        'Kulas Inc': 137351.96,
        'Trantow-Barrows': 123381.38,
        'White-Trantow': 135841.99,
        'Will LLC': 104437.60}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)

#data里面是自动，包括key和value

# %%
group_data
# Out:
# [109438.5,
#  103569.59,
#  112214.71,
#  112591.43,
#  100934.3,
#  103660.54,
#  137351.96,
#  123381.38,
#  135841.99,
#  104437.6]

# %%
group_names
# Out:
# ['Barton LLC',
#  'Frami, Hills and Schmidt',
#  'Fritsch, Russel and Anderson',
#  'Jerde-Hilpert',
#  'Keeling LLC',
#  'Koepp Ltd',
#  'Kulas Inc',
#  'Trantow-Barrows',
#  'White-Trantow',
#  'Will LLC']

# %%
group_mean
# Out:
# 114342.2

# %% [markdown]
# 1. 产生一个画图的对象，（fig，ax）

# %%
fig, ax = plt.subplots() #subplots绘制子图 fig, ax = plt.subplots( 2,2) #
plt.grid(False)#没有网格

# %%
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.style.use('fivethirtyeight') #调用风格，如果不想这个风格，可以运用kernel重启

# %%
fig, ax = plt.subplots()#建立空图
ax.barh(group_names, group_data)#建立横轴
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
plt.rcParams.update({'figure.autolayout': True})

fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
# Out:
# [Text(0, 0.5, 'Company'),
#  (-10000, 140000),
#  Text(0.5, 0, 'Total Revenue'),
#  Text(0.5, 1.0, 'Company Revenue')]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
# Out:
# [Text(0, 0.5, 'Company'),
#  (-10000, 140000),
#  Text(0.5, 0, 'Total Revenue'),
#  Text(0.5, 1.0, 'Company Revenue')]

# %%
def currency(x, pos):
    """The two args are the value and tick position"""
    if x >= 1e6:
        s = '${:1.1f}M'.format(x*1e-6)
    else:
        s = '${:1.0f}K'.format(x*1e-3)
    return s

formatter = FuncFormatter(currency)

# %%
currency(30000,1)
# Out:
# '$30K'

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
ax.xaxis.set_major_formatter(formatter)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')

# Add a vertical line, here we set the style in the function call
ax.axvline(group_mean, ls='--', color='r') #在ax上画一个横线，里面有均值，ls表示线条形状，颜色是红色

# Annotate new companies
for group in [0, 5, 8]:
    ax.text(145000, group, "New Company", fontsize=10,
            verticalalignment="center")

# Now we'll move our title up since it's getting a little cramped
ax.title.set(y=1.05)

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
ax.xaxis.set_major_formatter(formatter)
ax.set_xticks([0, 25e3, 50e3, 75e3, 100e3, 125e3])
fig.subplots_adjust(right=.1) #调整边距

plt.show()

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'ps': 'Postscript', 'eps': 'Encapsulated Postscript', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format'}

# %%
fig.savefig('sales.png', transparent=False, dpi=80, bbox_inches="tight") #保存图片，png格式

# %%
fig.savefig('sales.pdf', transparent=False, dpi=80, bbox_inches="tight") #保存图片，pdf格式

# %%
from matplotlib.backends.backend_pdf import PdfPages
with PdfPages('twopages.pdf') as pdf:
    plt.plot([1,2,3,4,5])
    pdf.savefig()
    plt.close()
    
    plt.plot([3,4,5,6,7])
    pdf.savefig()
    plt.close()

# %% [markdown]
# ## 第三节 图片的布局

# %%
#plt.style.use('default') #设置成默认格式

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.gridspec as gridspec
import numpy as np


plt.rcParams['savefig.facecolor'] = "0.8"  #color的亮度为0.8
plt.rcParams['figure.figsize'] = 4.4, 4. 


def example_plot(ax, fontsize=12, nodec=False): #画图函数，ax坐标系，
    ax.plot([1, 2]) #在坐标系画1,2两个参数

    ax.locator_params(nbins=3)
    if not nodec:
        ax.set_xlabel('x-label', fontsize=fontsize)
        ax.set_ylabel('y-label', fontsize=fontsize)
        ax.set_title('Title', fontsize=fontsize)
    else:
        ax.set_xticklabels('')
        ax.set_yticklabels('')


fig, ax = plt.subplots()
example_plot(ax, fontsize=24)
plt.show()

# %%
fig, axs = plt.subplots(2, 2, constrained_layout=True) #画一个2 x 2的图
for ax in axs.flat:
    example_plot(ax)

# %%
ax1 = plt.subplot(221)
ax2 = plt.subplot(223)
ax3 = plt.subplot(122)

example_plot(ax1)
example_plot(ax2)
example_plot(ax3)
plt.tight_layout() #将图片分开

# %%
fig = plt.figure()

ax1 = plt.subplot2grid((3, 3), (0, 0))
ax2 = plt.subplot2grid((3, 3), (0, 1), colspan=2)
ax3 = plt.subplot2grid((3, 3), (1, 0), colspan=2, rowspan=2)
ax4 = plt.subplot2grid((3, 3), (1, 2), rowspan=2)

example_plot(ax1)
example_plot(ax2)
example_plot(ax3)
example_plot(ax4)
plt.tight_layout()

# %% [markdown]
# ## 第四节 统计图表

# %% [markdown]
# 直方图

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

# example data
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(437)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=1)

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()

# %% [markdown]
# ## boxplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# rectangular box plot
bplot1 = axes[0].boxplot(all_data,
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                         labels=labels)  # will be used to label x-ticks
axes[0].set_title('Rectangular box plot')

# notch shape box plot
bplot2 = axes[1].boxplot(all_data,
                         notch=True,  # notch shape
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                         labels=labels)  # will be used to label x-ticks
axes[1].set_title('Notched box plot')

# fill with colors
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# adding horizontal grid lines
for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xlabel('Three separate samples')
    ax.set_ylabel('Observed values')

plt.show()

# %% [markdown]
# ## error bars

# %%
import numpy as np
import matplotlib.pyplot as plt

# example data
x = np.arange(0.1, 4, 0.5)
y = np.exp(-x)

# example error bar values that vary with x-position
error = 0.1 + 0.2 * x

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True)
ax0.errorbar(x, y, yerr=error, fmt='-o')
ax0.set_title('variable, symmetric error')

# error bar values w/ different -/+ errors that
# also vary with the x-position
lower_error = 0.4 * error
upper_error = error
asymmetric_error = [lower_error, upper_error]

ax1.errorbar(x, y, xerr=asymmetric_error, fmt='o')
ax1.set_title('variable, asymmetric error')
ax1.set_yscale('log')
plt.show()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# 更多的内容，请参阅 https://matplotlib.org/tutorials/index.html

# %% [markdown]
# 作业：真对第一次作业的数据：附件的曲线数据(sample1.txt)，对曲线分段、画图、存成pdf文件。
# 具体图片格式如图所示。
# - 1.每一组曲线数据，画两个图
#
#     - （1） torque vs angel 曲线图
#
#     - （2） torque VS time 和 angel vs time
# - 2.根据图像，将曲线图分为两段或两阶段。 下图是一个example

# %% [markdown]
# ![curve1.png](attachment:curve1.png)

# %% [markdown]
# ![curve2.png](attachment:curve2.png)

# %%
#上图是拧螺丝的过程，横轴是时间
