# %% [markdown]
# ## Python与爬虫基础

# %% [markdown]
# 主讲人： 贾金柱
# email： jzjia@math.pku.edu.cn

# %% [markdown]
# 助教：
# - 孔文佳  wjkong@pku.edu.cn
# - 王君    jwwwang@pku.edu.cn
# - 张鉴心  zhangjx43@pku.edu.cn
# - 冯和宁  fenghn9@pku.edu.c

# %% [markdown]
# 第一次课 Python基础
#
# 时间：9月11日 周三10-12节（18:40-21:30）

# %% [markdown]
# ## 第一章 Python基础

# %% [markdown]
# 为什么要学习python？

# %% [markdown]
# ![schedule.png](attachment:schedule.png)

# %% [markdown]
# Python的安装
#
# - python 主要有两个版本：python2.x 和 python3.x
# - 本课主要使用python3.x
# - python 有很多版本，我们使用Anaconda, Anaconda3

# %% [markdown]
# python 程序的编写

# %% [markdown]
# - 一般需要一个编辑器。常用的编辑器有：sublime，atom，pycharm......
#
# - 然后需要一个python解释器，常用的是ipython
#
# - 我们使用jupyter

# %% [markdown]
# python 的第一个程序

# %%
sum(range(100))
# Out:
# 4950

# %% [markdown]
# python 当作计算器

# %%
(1+100)*100/2
# Out:
# 5050.0

# %%
(1+99)*99/2
# Out:
# 4950.0

# %% [markdown]
# $$\int_1^2 xdx$$

# %%
from sympy import *
x = symbols('x')
print(integrate(x, (x, 1, 2)))
# Out:
# 3/2

# %% [markdown]
# 输入和输出

# %%
x1 = 1
x2 = 13
x = int(input()) ## 输入
while(1):
    print('x=%d,比目标大吗？'%x) ## 输出
    y = input() ## 输入
    if y=='yes':
        x2 = x
        x = (x+x1)//2
    if y=='no':
        print('x=%d,比目标小吗？'%x) ## 输出
        y = input()
        if y=='yes':
            x1 = x
            x = (x+x2)//2
        else:
            print('恭喜你，猜对了！真相只有一个，它就是%d!'%x)
            break
# Out:
# 5
# x=5,比目标大吗？
# no
# x=5,比目标小吗？
# yes
# x=9,比目标大吗？
# no
# x=9,比目标小吗？
# no
# 恭喜你，猜对了！真相只有一个，它就是9!

# %% [markdown]
# 本章将学习到什么？
#
# - python 数据类型
# - 程序的控制流
# - 编写自己的函数
# - 文件读写操作

# %% [markdown]
# ## 第一节 python 最基础知识：数据类型

# %% [markdown]
# 整数、小数、字符串、布尔值

# %%
[10,2,3,1.2E-3,-3e4,1e2,'It', 'is', "a", 'good', 'day','great!',True,False]
# Out:
# [10,
#  2,
#  3,
#  0.0012,
#  -30000.0,
#  100.0,
#  'It',
#  'is',
#  'a',
#  'good',
#  'day',
#  'great!',
#  True,
#  False]

# %% [markdown]
# 注：python中单引号和双引号没有区别

# %% [markdown]
# 转义字符

# %%
print('I\'m \"OK\"!')
# Out:
# I'm "OK"!

# %%
print('I\'m learning\n"Python\".\tWhat are you doing?\\')
# Out:
# I'm learning
# "Python".	What are you doing?\

# %%
print('''hello,
world''')

# %%
print(r'C:\folder\n') ## raw strings（原始字字符串）
# Out:
# C:\folder\n

# %% [markdown]
# 布尔运算

# %%
[True,2>1,3>2,3>2>1,3>2 and 2>1, 3>2 or 1>2, not 1>2]
# Out:
# [True, True, True, True, True, True, True]

# %% [markdown]
# 布尔值经常用在判断语句中

# %%
score = 86
if score > 85:
    print('成绩优秀')
# Out:
# 成绩优秀

# %%
[1,2,3,None,4,5,6] ## None 是空值，一种特殊的类型，表示什么都没有

# %% [markdown]
# 变量

# %% [markdown]
# - 变量用来存储数据，它的值可以改变。
# - 在程序中每一个变量都有一个变量名，用英文字母、数字和下划线表示。
# - 不能以数字开头

# %%
x=1
x1=2
x2 = 3
x_good = 100
_x = 5

# %%
[x+1,x1+2,x2+3,x_good-1,_x + 1]
# Out:
# [2, 4, 6, 99, 6]

# %% [markdown]
# **动态语言**的特点：
# - 不需事先声明变量的类型
# - 变量的类型可以改变
# 如：

# %%
x = 1
print(x)
x='你好'
print(x)
# Out:
# 1
# 你好

# %%
a = 'ABC'
b = a
a = 'XYZ'
print(b)
# Out:
# ABC

# %% [markdown]
# 执行 a= 'ABC'时，解释器创建了字符串"ABC",同时创建了变量a，并把a指向字符串

# %% [markdown]
# ![a0.png](attachment:a0.png)

# %% [markdown]
# 执行b=a时，解释器创建了变量b，并把a指向的内容指向了b

# %% [markdown]
# ![a1.png](attachment:a1.png)

# %% [markdown]
# 执行 a= 'XYZ'时，解释器创建了字符串"XYZ",同时把a的指向改变了，指向新建立的字符串

# %% [markdown]
# ![a2.png](attachment:a2.png)

# %% [markdown]
# 一些特殊的操作（运算）

# %%
[10/3,10//3,10%3]
# Out:
# [3.3333333333333335, 3, 1]

# %% [markdown]
# 字符串操作
# - 字符串的长度
# - 字符串的提取
# - 字符串的替换
# - 格式化
# - 字符串编码问题

# %%
x = "I am very happy today!"
print(x)
# Out:
# I am very happy today!

# %%
len(x)
# Out:
# 22

# %%
x.split(' ')
# Out:
# ['I', 'am', 'very', 'happy', 'today!']

# %%
# ?x.replace

# %%
x.replace('!','')
# Out:
# 'I am very happy today'

# %%
x.replace('I am','You are')
# Out:
# 'You are very happy today!'

# %%
[x.replace('y','e'),x.replace('y','e',2)]
# Out:
# ['I am vere happe todae!', 'I am vere happe today!']

# %% [markdown]
# 格式化

# %%
"%s同学，你的期末考试成绩是 %f，恭喜你，你击败了 %f%%的同类！"%('王思聪',95,(160-2.0)/160*100)
# Out:
# '王思聪同学，你的期末考试成绩是 95.000000，恭喜你，你击败了 98.750000%的同类！'

# %%
print("%s同学，你的期末考试成绩是 %f，恭喜你，你击败了 %f%%的同类！"%('王思聪',95,(160-2.0)/160*100))
# Out:
# 王思聪同学，你的期末考试成绩是 95.000000，恭喜你，你击败了 98.750000%的同类！

# %%
print("%s同学，你的期末考试成绩是 %s，恭喜你，你击败了 %s%%的同类！"%('王思聪',95,(160-2.0)/160*100))
# Out:
# 王思聪同学，你的期末考试成绩是 95，恭喜你，你击败了 98.75%的同类！

# %%
print("%s同学，你的期末考试成绩是 %.1f，恭喜你，你击败了 %.2f%%的同类！"%('王思聪',95,(160-2.0)/160*100))
# Out:
# 王思聪同学，你的期末考试成绩是 95.0，恭喜你，你击败了 98.75%的同类！

# %%
print("{0}同学，你的期末考试成绩是{1}，恭喜你，你击败了 {2}%的同类！".format('王思聪',95,(160-2.0)/160*100))
# Out:
# 王思聪同学，你的期末考试成绩是95，恭喜你，你击败了 98.75%的同类！

# %%
print("{0}同学，你的期末考试成绩是{1:.1f}，恭喜你，你击败了 {2}%的同类！".format('王思聪',95,(160-2.0)/160*100))
# Out:
# 王思聪同学，你的期末考试成绩是95.0，恭喜你，你击败了 98.75%的同类！

# %%
print('%2d-%02d' % (3, 1))## d代表整数，2代表这个数字占两位字符；
print('%.2f' % 3.1415926)
# Out:
#  3-01
# 3.14

# %% [markdown]
# 编码问题

# %% [markdown]
# 字符串是一种数据类型，但是，字符串比较特殊的是还有一个编码问题。

# %% [markdown]
# 因为计算机只能处理数字，如果要处理文本，就必须先把文本转换为数字才能处理。最早的计算机在设计时采用8个比特（bit）作为一个字节（byte），所以，一个字节能表示的最大的整数就是255（二进制11111111=十进制255），如果要表示更大的整数，就必须用更多的字节。比如两个字节可以表示的最大整数是65535，4个字节可以表示的最大整数是4294967295。

# %% [markdown]
# 由于计算机是美国人发明的，因此，最早只有127个字符被编码到计算机里，也就是大小写英文字母、数字和一些符号，这个编码表被称为ASCII编码，比如大写字母A的编码是65，小写字母z的编码是122。

# %% [markdown]
# 但是要处理中文显然一个字节是不够的，至少需要两个字节，而且还不能和ASCII编码冲突，所以，中国制定了GB2312编码，用来把中文编进去。

# %% [markdown]
# 你可以想得到的是，全世界有上百种语言，日本把日文编到Shift_JIS里，韩国把韩文编到Euc-kr里，各国有各国的标准，就会不可避免地出现冲突，结果就是，在多语言混合的文本中，显示出来会有乱码。

# %% [markdown]
# 因此，Unicode应运而生。Unicode把所有语言都统一到一套编码里，这样就不会再有乱码问题了。

# %% [markdown]
# 现在，捋一捋ASCII编码和Unicode编码的区别：ASCII编码是1个字节，而Unicode编码通常是2个字节。
#
# 字母A用ASCII编码是十进制的65，二进制的01000001；
#
# 字符0用ASCII编码是十进制的48，二进制的00110000，注意字符'0'和整数0是不同的；
#
# 汉字中已经超出了ASCII编码的范围，用Unicode编码是十进制的20013，二进制的01001110 00101101。
#
# 你可以猜测，如果把ASCII编码的A用Unicode编码，只需要在前面补0就可以，因此，A的Unicode编码是00000000 01000001。
#
# 新的问题又出现了：如果统一成Unicode编码，乱码问题从此消失了。但是，如果你写的文本基本上全部是英文的话，用Unicode编码比ASCII编码需要多一倍的存储空间，在存储和传输上就十分不划算。
#
# 所以，本着节约的精神，又出现了把Unicode编码转化为“可变长编码”的UTF-8编码。UTF-8编码把一个Unicode字符根据不同的数字大小编码成1-6个字节，常用的英文字母被编码成1个字节，汉字通常是3个字节，只有很生僻的字符才会被编码成4-6个字节。如果你要传输的文本包含大量英文字符，用UTF-8编码就能节省空间：

# %% [markdown]
# ![utf-8.png](attachment:utf-8.png)

# %% [markdown]
# 从上面的表格还可以发现，UTF-8编码有一个额外的好处，就是ASCII编码实际上可以被看成是UTF-8编码的一部分，所以，大量只支持ASCII编码的历史遗留软件可以在UTF-8编码下继续工作。

# %%
'王思聪'.encode('utf-8')
# Out:
# b'\xe7\x8e\x8b\xe6\x80\x9d\xe8\x81\xaa'

# %%
'中文'.encode('utf-8')
# Out:
# b'\xe4\xb8\xad\xe6\x96\x87'

# %%
'ABC'.encode('ascii')
# Out:
# b'ABC'

# %%
b'\xe4\xb8\xad\xe6\x96\x87'.decode('utf-8')
# Out:
# '中文'

# %% [markdown]
# 由于Python源代码也是一个文本文件，所以，当你的源代码中包含中文的时候，在保存源代码时，就需要务必指定保存为UTF-8编码。当Python解释器读取源代码时，为了让它按UTF-8编码读取，我们通常在文件开头写上这两行：

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %% [markdown]
# 第一行注释是为了告诉Linux/OS X系统，这是一个Python可执行程序，Windows系统会忽略这个注释；
#
# 第二行注释是为了告诉Python解释器，按照UTF-8编码读取源代码，否则，你在源代码中写的中文输出可能会有乱码。

# %% [markdown]
# 几种常用的Python内置数据结构
# - list
# - tuple
# - dict
# - set

# %% [markdown]
# list: 有序集合。可以添加、删除、插入数据。

# %%
classmates = ['Jim','Peter','Li Lei'] ## list 的创建

# %%
len(classmates)
# Out:
# 3

# %%
classmates[0],classmates[2],classmates[1]
# Out:
# ('Jim', 'Li Lei', 'Peter')

# %%
classmates[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-81a27e3ce05f> in <module>
# ----> 1 classmates[3]
#
# IndexError: list index out of range

# %%
(classmates[-1],classmates[-2],classmates[-3])
# Out:
# ('Li Lei', 'Peter', 'Jim')

# %%
classmates.append('Han Meimei')

# %%
classmates
# Out:
# ['Jim', 'Peter', 'Li Lei', 'Han Meimei']

# %%
classmates.insert(1,'Jack')

# %%
classmates
# Out:
# ['Jim', 'Jack', 'Peter', 'Li Lei', 'Han Meimei']

# %%
classmates.pop()
# Out:
# 'Han Meimei'

# %%
classmates
# Out:
# ['Jim', 'Jack', 'Peter', 'Li Lei']

# %%
classmates.pop(2)
# Out:
# 'Peter'

# %%
classmates
# Out:
# ['Jim', 'Jack', 'Li Lei']

# %%
classmates[1] = 'Sicong'

# %%
classmates
# Out:
# ['Jim', 'Sicong', 'Li Lei']

# %%
['Apple','Banana','ipad',3,1,1000,True,False,None]
# Out:
# ['Apple', 'Banana', 'ipad', 3, 1, 1000, True, False, None]

# %%
L=[['Apple','Banana'],'ipad',[3,1,1000],[True,False,None]]

# %%
len(L)
# Out:
# 4

# %%
L[0][0]
# Out:
# 'Apple'

# %%
L=[]

# %%
len(L)
# Out:
# 0

# %% [markdown]
# tuple

# %% [markdown]
# tuple:和list类似，不同的是，tuple的元素**不可改变！**更安全！

# %%
t = (1,2,3)

# %%
t,type(t)
# Out:
# ((1, 2, 3), tuple)

# %%
t=(1,2)

# %%
t,type(t)
# Out:
# ((1, 2), tuple)

# %%
t=(1)###陷阱

# %%
t,type(t)
# Out:
# (1, int)

# %%
t=(1,)

# %%
t,type(t)
# Out:
# ((1,), tuple)

# %%
a=[1,2,3]
b=a
a[2]=4

# %%
b ### b 也变化了！！！！
# Out:
# [1, 2, 4]

# %% [markdown]
# Set

# %% [markdown]
# set:可以看成数学意义上的无序和无重复元素的集合，因此，两个set可以做数学意义上的交集、并集等操作：

# %%
s1 = set([1, 2, 3])
s2 = set([1, 2, 4])

# %%
s1 & s2
# Out:
# {1, 2}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4}

# %%
s1.add(4)

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.remove(4)

# %%
s1
# Out:
# {1, 2, 3}

# %%
x = [1,2,3,4,5,4,3,2,1]

# %%
set(x)
# Out:
# {1, 2, 3, 4, 5}

# %%
x = {1,2,3,2,1}

# %%
x
# Out:
# {1, 2, 3}

# %%
t = ('a', 'b', ['A', 'B'])
t[2][0] = 'X'
t[2][1] = 'Y'

# %%
t
# Out:
# ('a', 'b', ['X', 'Y'])

# %% [markdown]
# Dict

# %% [markdown]
# Dict,很多书上又称为健值对（key:value） pairs,具有极快的查询速度。

# %%
names = ['Michael', 'Bob', 'Tracy']
scores = [95, 75, 85]

# %%
d = {'Michael': 95, 'Bob': 75, 'Tracy': 85}

# %%
d
# Out:
# {'Michael': 95, 'Bob': 75, 'Tracy': 85}

# %%
d['Bob']
# Out:
# 75

# %%
d['Jim'] = 90

# %%
d
# Out:
# {'Michael': 95, 'Bob': 75, 'Tracy': 85, 'Jim': 90}

# %%
d['Li Lei']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-a6ffd4375a17> in <module>
# ----> 1 d['Li Lei']
#
# KeyError: 'Li Lei'

# %%
'Li Lei' in d
# Out:
# False

# %%
d.get('Jim')
# Out:
# 90

# %%
d.get('Li Lei')

# %%
d.get('Li Lei',-1)
# Out:
# -1

# %%
d.pop('Jim')
# Out:
# 90

# %%
d
# Out:
# {'Michael': 95, 'Bob': 75, 'Tracy': 85}

# %% [markdown]
# 请务必注意，dict内部存放的顺序和key放入的顺序是没有关系的。
#
# 和list比较，dict有以下几个特点：
#
#     查找和插入的速度极快，不会随着key的增加而变慢；
#     需要占用大量的内存，内存浪费多。
#
# 而list相反：
#
#     查找和插入的时间随着元素的增加而增加；
#     占用空间小，浪费内存很少。
#
# 所以，dict是用空间来换取时间的一种方法。

# %% [markdown]
# dict可以用在需要高速查找的很多地方，在Python代码中几乎无处不在，正确使用dict非常重要，需要牢记的第一条就是dict的key必须是不可变对象。

# %%
d.keys()
# Out:
# dict_keys(['Michael', 'Bob', 'Tracy'])

# %%
d.values()
# Out:
# dict_values([95, 75, 85])

# %% [markdown]
# 可变对象和不可变对象

# %% [markdown]
# 对于可变对象，比如list，对list进行操作，list内部的内容是会变化的，比如：

# %%
a = ['c', 'b', 'a']

# %%
a.sort()

# %%
a ## a 变化了
# Out:
# ['a', 'b', 'c']

# %%
a = 'abc'

# %%
a.replace('a','A')
# Out:
# 'Abc'

# %%
a ## a 不变
# Out:
# 'abc'

# %% [markdown]
# ## 第二节 控制流

# %% [markdown]
# - 条件
# - 循环

# %% [raw]
# if <条件判断1>:
#     <执行1>
# elif <条件判断2>:
#     <执行2>
# elif <条件判断3>:
#     <执行3>
# else:
#     <执行4>

# %%
age = 3
if age >= 18:
    print('adult')
elif age >= 6:
    print('teenager')
else:
    print('kid')
# Out:
# kid

# %%
age = 20
if age >= 6:
    print('teenager')
elif age >= 18:
    print('adult')
else:
    print('kid')
# Out:
# teenager

# %% [markdown]
# if语句执行有个特点，它是从上往下判断，如果在某个判断上是True，把该判断对应的语句执行后，就忽略掉剩下的elif和else，所以，请测试并解释为什么下面的程序打印的是teenager：

# %% [markdown]
# 循环
# - for
# - while
# - break
# - continue

# %%
for name in ['Bob','Jim','Li Lei']:
    print('send %s an email!'%name)
# Out:
# send Bob an email!
# send Jim an email!
# send Li Lei an email!

# %%
names = ['Bob','Jim','Li Lei']
k = 0
while(1):
    name = names[k]
    print('send %s an email!'%name)
    k = k+1
    if k >=len(names):
        break

# %%
for i in range(10):
    if i%2 ==0:
        continue
    else:
        print('%d is an odd number!'%i)
# Out:
# 1 is an odd number!
# 3 is an odd number!
# 5 is an odd number!
# 7 is an odd number!
# 9 is an odd number!

# %% [markdown]
# # 第三节 函数

# %% [markdown]
# python 内置了很多函数，正确调用函数可以高效地完成任务

# %%
abs(-100),min(1,2,3),min([1,2,3])
# Out:
# (100, 1, 1)

# %%
min([1,2,3],[1,2])
# Out:
# [1, 2]

# %%
int('123'),float('1.2'),str(100)
# Out:
# (123, 1.2, '100')

# %% [markdown]
# 函数名是可以改变的，和变量名意义类似，函数名是用来存放函数的，所以它指向一个函数

# %%
my_abs = abs

# %%
my_abs(-100)
# Out:
# 100

# %% [markdown]
# 自定义函数

# %%
def quadratic(x,a=1,b=2,c=0): ## 默认参数，必须放在最后，且是不可变对象
    res = a*x**2+b*x+c
    return res

# %%
import numpy as np
x = np.linspace(-5,3,20)
y = quadratic(x)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
def fact(n):
    if n==1:
        return 1
    return n * fact(n - 1) ## 在函数内部调用自身，这样的函数叫递归函数

# %%
fact(6)
# Out:
# 720

# %% [markdown]
# ## 第四节 文件操作

# %%
f = open('./test.txt', 'w')
f.write('Hello, world!')
f.close()

# %%
with open('./test.txt', 'w') as f:
    f.write('Hello, world!')

# %%
f = open('./test.txt', 'r')
f.read()
f.close()

# %%
with open('./test.txt', 'r') as f:
    print(f.read())

# %% [markdown]
# 序列化

# %% [markdown]
# 我们把变量从内存中变成可存储或传输的过程称之为序列化，在Python中叫pickling，在其他语言中也被称之为serialization，marshalling，flattening等等，都是一个意思。
#
# 序列化之后，就可以把序列化后的内容写入磁盘，或者通过网络传输到别的机器上。
#
# 反过来，把变量内容从序列化的对象重新读到内存里称之为反序列化，即unpickling。
#
# Python提供了pickle模块来实现序列化。

# %%
import pickle
d = dict(name='Bob', age=30, score=88)
f = open('dump.pkl', 'wb')
pickle.dump(d, f)
f.close()

# %%
f = open('dump.pkl', 'rb')
d = pickle.load(f)
f.close()
d

# %% [markdown]
# ## 第五节 一些高级特性

# %%
L = ['Michael', 'Sarah', 'Tracy', 'Bob', 'Jack']

# %%
L[:3] ## 切片，slice

# %%
L[3:]

# %%
L[:]

# %%
L[:-1]

# %%
L[-1:]

# %%
L = list(range(100))

# %%
L[:10:2]

# %%
L[::5]

# %%
"ABCDE"[1:5:2],"ABCDE"[-1:-5:-1]

# %%
[x * x for x in range(1, 11)] ## 列表生成式

# %% [markdown]
# ## 作业

# %% [markdown]
# 1.用python写出一个数学竖式。
#
# 用键盘输入三个量：第一个数字、第二个数字、+或-号
#
# 输出：一个漂亮的数学竖式，如下图所示。
#
# ![math.png](attachment:math.png)

# %% [markdown]
# 2.用python编写24点小游戏。
#
# 要求：从键盘输入4个数字，每个在1-10（包含）之间
#
# 判断是否可以用 +-\*/ 通过运算得到结果24，并输出运算过程
#
# 结果越简洁越好
#
# ![twenty4.png](attachment:twenty4.png)

# %% [markdown]
# 3.对附件的英文小说: pride_and_prejudice.txt
#
# 统计出其中使用的单词数量，
#
# 并计算每一个单词的出现次数。
#
# Report最多的10个单词。

# %% [markdown]
# 4.找出10000以内的所有孪生素数对。

# %% [raw]
# 5.针对附件的曲线数据(sample.txt)，画出曲线图。(最后的曲线图处，有一个详细的说明，包括横轴、纵轴分别是什么)
#
#    数据读取后，数据长成这样：

# %%
import csv
lines = []
with open('sample.txt', 'r') as csvf:
    k = 0
    for line in csv.reader(csvf):
        k = k +1
        lines.append(line[0].split('\t'))

# %%
lines[0][0],lines[0][0][1:]
# Out:
# ('\ufeff18286230', '18286230')

# %%
lines[0]
# Out:
# ['\ufeff18286230',
#  '2019-04-19 19:33:42.000',
#  '-2',
#  '1.5',
#  '0',
#  '...',
#  '76271592                                          ']

# %%
lines[1]

# %% [markdown]
# 各列名字如下：'id1','timestamp','ind','sampleTime','angleOffset','codes','identifier'

# %% [markdown]
# id1: 曲线id；ind=-1：代表是Torque数据；ind = -2:代表是Angle数据，sampleTime 代表多久采样一次；codes是真正的数据

# %%
import struct
codes = lines[0][5]
hexcode = codes[2:10]
print(hexcode)
bts = bytes.fromhex(hexcode)
print(bts)
struct.unpack('<f',bts)
struct.unpack('<f',bts)[0]
# Out:
# 00000000
# b'\x00\x00\x00\x00'
# 0.0

# %%
codes = lines[0][5]
hexcode = codes[10:18]
print(hexcode)
bts = bytes.fromhex(hexcode)
print(bts)
struct.unpack('<f',bts)
struct.unpack('<f',bts)[0]
# Out:
# E416B13E
# b'\xe4\x16\xb1>'
# 0.3458777666091919

# %% [markdown]
# ![curves.png](attachment:curves.png)

# %% [markdown]
# 这幅图中，横轴代表angle，纵轴代表toruqe。在数据中，id1相同的两行数据，一行代表torque（ind=-1），一行代表angle（ind=-2）。数据都是用codes表示的。需要先解码。有了angle 和 torque，就可以画上面的图形了。多次调用plt.plot(),可以同时画出所有的曲线。

# %% [markdown]
# 第二次课 【停课】
# 时间：9月13日 周五10-12节（18:40-21:30） 【停课】

# %% [markdown]
# 第二次课 Python的面向对象编程
# 时间：9月18日 周三10-12节（18:40-21:30）

# %% [markdown]
# ## 第二章 面向对象编程

# %% [markdown]
# 面向对象最重要的概念就是类（Class）和实例（Instance）
#
# - 类，类型的简称，相当于自定制的新的类型
# - 类是模板，是抽象的
# - 而实例是具体的，根据类创建出来的一个个具体的“对象”
# - 每个对象都拥有相同的方法，但各自的数据可能不同。
# - 类和函数一样，可以大大地减少代码的重复编写

# %% [markdown]
# 例如：在终端输出如下信息

# %% [markdown]
# 小明，10岁，男，上山去砍柴
#
# 小明，10岁，男，骑车去东北
#
# 小明，10岁，男，最爱打游戏
#
# ........
#
#
# 老李，90岁，男，上山去砍柴
#
# 老李，90岁，男，开车去东北
#
# 老李，90岁，男，最爱打游戏

# %%
def kanchai(name, age, gender):
    print("%s,%s岁,%s,上山去砍柴" %(name, age, gender))
 
 
def qudongbei(name, age, gender):
    print("%s,%s岁,%s,开车去东北" %(name, age, gender))
 
 
def dayouxi(name, age, gender):
    print("%s,%s岁,%s,最爱打游戏" %(name, age, gender))

# %%
kanchai('小明', 10, '男')
qudongbei('小明', 10, '男')
dayouxi('小明', 10, '男')

kanchai('老李', 90, '男')
qudongbei('老李', 90, '男')
dayouxi('老李', 90, '男')
# Out:
# 小明,10岁,男,上山去砍柴
# 小明,10岁,男,开车去东北
# 小明,10岁,男,最爱打游戏
# 老李,90岁,男,上山去砍柴
# 老李,90岁,男,开车去东北
# 老李,90岁,男,最爱打游戏

# %%
class sport:
     
    def __init__(self, name, age ,gender):
        self.name = name
        self.age = age
        self.gender = gender
 
    def kanchai(self):
        print("%s,%s岁,%s,上山去砍柴" %(self.name, self.age, self.gender))
 
    def qudongbei(self):
        print("%s,%s岁,%s,开车去东北" %(self.name, self.age, self.gender))
 
    def dayouxi(self):
        print("%s,%s岁,%s,最爱打游戏" %(self.name, self.age, self.gender))

# %%
xiaoming = sport('小明', 10, '男')
xiaoming.kanchai()
xiaoming.qudongbei()
xiaoming.dayouxi()
 
laoli = sport('老李', 90, '男')
laoli.kanchai()
laoli.qudongbei()
laoli.dayouxi()
# Out:
# 小明,10岁,男,上山去砍柴
# 小明,10岁,男,开车去东北
# 小明,10岁,男,最爱打游戏
# 老李,90岁,男,上山去砍柴
# 老李,90岁,男,开车去东北
# 老李,90岁,男,最爱打游戏

# %% [markdown]
# ## 第一节 类和实例

# %%
class Student(object):
    pass

# %% [markdown]
# `class`后面紧接着是类名，即`Student`，类名通常是大写开头的单词，紧接着是(`object`)，表示该类是从哪个类继承下来的，继承的概念我们后面再讲，通常，如果没有合适的继承类，就使用`object`类，这是所有类最终都会继承的类 **[可以不写]**。

# %% [markdown]
# 定义好了Student类（它是一个新类型），就可以根据Student类（型）创建出Student的实例（变量），创建实例是通过类名+()实现的：

# %%
Sicong = Student()

# %%
Sicong

# %%
Student
# Out:
# __main__.Student

# %% [markdown]
# 可以看到，变量Sicong指向的就是一个Student的实例，后面的0x......是内存地址，每个object的地址都不一样，而Student本身则是一个类。

# %% [markdown]
# 可以自由地给一个实例变量绑定属性，比如，给实例Sicong绑定一个name属性和一个score属性：

# %%
Sicong.name = 'Sicong Wang'

# %%
Sicong

# %%
Sicong.score = 99

# %%
Sicong.name,Sicong.score
# Out:
# ('Sicong Wang', 99)

# %% [markdown]
# 由于类可以起到模板的作用，因此，可以在创建实例的时候，把一些我们认为必须绑定的属性强制填写进去。通过定义一个特殊的\_\_init\_\_方法，在创建实例的时候，就把name，score等属性绑上去：

# %%
class Student(object):

    def __init__(self, name, score):
        self.name = name
        self.score = score

# %% [markdown]
# \_\_init\_\_方法的第一个参数永远是self，表示创建的实例本身，因此，在\_\_init\_\_方法内部，就可以把各种属性绑定到self，因为self就指向创建的实例本身。
#
# 有了\_\_init\_\_方法，在创建实例的时候，就不能传入空的参数了，必须传入与\_\_init\_\_方法匹配的参数，但self不需要传，Python解释器自己会把实例变量传进去：

# %%
Sicong = Student('Sicong Wang',95)

# %%
Sicong,print(Sicong)
# Out:
# ...
# (<__main__.Student at 0x199dd0189e8>, None)

# %%
Sicong.name,Sicong.score
# Out:
# ('Sicong Wang', 95)

# %% [markdown]
# 和普通的函数相比，在类中定义的函数只有一点不同，就是第一个参数永远是实例变量self，并且调用时，不用传递该参数。除此之外，类的方法和普通函数没有什么区别，所以，你仍然可以用默认参数等。

# %%
class Student(object):

    def __init__(self, name, score):
        self.name = name
        self.score = score
    
    def __str__(self):
        return 'name: %s\nscore: %s'%(self.name, self.score)

# %%
Sicong = Student('Sicong Wang',95)

# %%
print(Sicong)
# Out:
# name: Sicong Wang
# score: 95

# %%
Sicong

# %%
class Student(object):

    def __init__(self, name, score):  #初始化，第一个是自己默认参数，后面是传入的参数
        self.name = name
        self.score = score
    
    def __str__(self): #class第一个是slef,后面没有表示不接受其他参数
        return 'name: %s\nscore: %s'%(self.name, self.score) #返回字符串
    __repr__ = __str__   #跟str方法一样

# %%
Sicong = Student('Sicong Wang',95)

# %%
Sicong #调用repr函数
# Out:
# name: Sicong Wang
# score: 95

# %% [markdown]
# - 在python中方法名如果是\_\_xxxx\_\_()的，那么就有特殊的功能，因此叫做“魔法”方法
# - 当使用print输出对象的时候，只要自己定义了\_\_str\_\_(self)方法，那么就会打印从在这个方法中return的数据
# - \_\_str\_\_方法需要返回一个字符串，当做这个对象的描写
# - \_\_repr\_\_ 也是用来描述对象的，一般和 \_\_str\_\_方法是一样的

# %% [markdown]
# **数据封装** 面向对象编程的一个重要特点就是数据封装。在上面的Student类中，每个实例就拥有各自的name和score这些数据。我们可以通过函数来访问这些数据，比如打印一个学生的成绩：

# %%
def print_score(std): #定义函数（std）
     print('%s: %s' % (std.name, std.score)) 

print_score(Sicong) #打印成绩
# Out:
# Sicong Wang: 95

# %% [markdown]
# 但是，既然Student实例本身就拥有这些数据，要访问这些数据，就没有必要从外面的函数去访问，可以直接在Student类的内部定义访问数据的函数，这样，就把“数据”给封装起来了。这些封装数据的函数是和Student类本身是关联起来的，我们称之为**类的方法**：

# %%
class Student(object):

    def __init__(self, name, score): #name,score是属性，是魔法函数，没有返回值
        self.name = name 
        self.score = score
    
    def __str__(self):
        return 'name: %s\nscore: %s'%(self.name, self.score)
    __repr__ = __str__
    
    def print_score(self):
        print('%s: %s' % (self.name, self.score))
        #问题：三个函数之间的关系？都是魔法函数，第一个函数没有返回值

# %%
Sicong = Student('Sicong Wang',95)

# %% [markdown]
# 要定义一个方法，除了第一个参数是self外，其他和普通函数一样。要调用一个方法，只需要在实例变量上直接调用，除了self不用传递，其他参数正常传入：

# %%
Sicong.print_score() #
# Out:
# Sicong Wang: 95

# %% [markdown]
# 这样一来，我们从外部看Student类，就只需要知道，创建实例需要给出name和score，而如何打印，都是在Student类的内部定义的，这些数据和逻辑被“封装”起来了，调用很容易，但却不用知道内部实现的细节。

# %% [markdown]
# 类其实就是自己定义的新的类型，和python内置的类型并没有本质不同。参考如下例子。

# %%
X = list(range(0,10,2)) #从0到10，不包含10，每隔2生成一个数

# %%
X
# Out:
# [0, 2, 4, 6, 8]

# %%
X.index(2)  #查看2在什么位置
# Out:
# 1

# %%
X.insert(1,1) #在第一个位置插入一个1

# %%
X
# Out:
# [0, 1, 2, 4, 6, 8]

# %% [markdown]
# **小结**
#
# - 类是创建实例的模板，是抽象的，而实例则是一个一个具体的对象，各个实例拥有的数据都互相独立，互不影响；
#
# - 方法就是与实例绑定的函数，和普通函数不同，方法可以直接访问实例的数据；（print可以直接访问）
#
# - 通过在实例上调用方法，我们就直接操作了对象内部的数据，但无需知道方法内部的实现细节。
#
# - 和静态语言不同，Python允许对实例变量绑定任何数据，也就是说，对于两个实例变量，虽然它们都是同一个类的不同实例，但拥有的变量名称都可能不同：
#
#
# -Q 类与实例、属性的区别?

# %%
Jim = Student('Jim Green', 80)
Lei = Student('Lei Li', 90)
Jim.age = 12
Jim.age
# Out:
# 12

# %%
Lei.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-b813b682d734> in <module>
# ----> 1 Lei.age
#
# AttributeError: 'Student' object has no attribute 'age'

# %% [markdown]
# ## 第二节 访问限制

# %% [markdown]
# 在Class内部，可以有属性和方法，而外部代码可以通过直接调用实例变量的方法来操作数据，这样，就隐藏了内部的复杂逻辑。
#
# 但是，从前面Student类的定义来看，外部代码还是可以自由地修改一个实例的name、score属性：

# %%
Jim = Student('Jim Green', 80)

# %%
Jim.score
# Out:
# 80

# %%
Jim.score =99

# %%
print(Jim)
# Out:
# name: Jim Green
# score: 99

# %% [markdown]
# 如果要让内部属性不被外部访问，可以把属性的名称前加上两个下划线\_\_，在Python中，实例的变量名如果以\_\_开头，就变成了一个私有变量（private），只有内部可以访问，外部不能访问，所以，我们把Student类改一改：

# %%
class Student(object):

    def __init__(self, name, score):
        self.__name = name
        self.__score = score
    
    def __str__(self):
        return 'name: %s\nscore: %s'%(self.__name, self.__score)#__name加下划线不能被访问
    __repr__ = __str__
    def print_score(self):
        print('%s: %s' % (self.__name, self.__score))

# %%
Jim = Student('Jim Green', 80)

# %%
print(Jim)
# Out:
# name: Jim Green
# score: 80

# %%
Jim
# Out:
# name: Jim Green
# score: 80

# %% [markdown]
# 改完后，对于外部代码来说，没什么变动，但是已经无法从外部访问实例变量.\_\_name和实例变量.\_\_score了：

# %%
bart.__name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-1e120ece361e> in <module>
# ----> 1 bart.__name
#
# NameError: name 'bart' is not defined

# %% [markdown]
# 这样就确保了外部代码不能随意修改对象内部的状态，这样通过访问限制的保护，代码更加健壮。
#
# 但是如果外部代码要获取name和score怎么办？可以给Student类增加get_name和get_score这样的方法：

# %%
class Student(object):

    def __init__(self, name, score):
        self.__name = name
        self.__score = score
    
    def __str__(self):
        return 'name: %s\nscore: %s'%(self.__name, self.__score)
    __repr__ = __str__

    
    def print_score(self):
        print('%s: %s' % (self.__name, self.__score))
    
    def get_name(self): 
        return self.__name  #在内部调用函数
    def get_score(self):
        return self.__score

# %%
bart = Student('Bart Simpson', 59)

# %%
bart
# Out:
# name: Bart Simpson
# score: 59

# %%
bart.get_name(),bart.get_score()
# Out:
# ('Bart Simpson', 59)

# %% [markdown]
# 问题：如果又要允许外部代码修改score怎么办？可以再给Student类增加set_score方法：

# %%
class Student(object):

    def __init__(self, name, score):
        self.__name = name
        self.__score = score
    
    def __str__(self):
        return 'name: %s\nscore: %s'%(self.__name, self.__score)
    
    def print_score(self):
        print('%s: %s' % (self.__name, self.__score))
    
    def get_name(self):
        return self.__name
    def get_score(self):
        return self.__score
    def set_score(self,score): ## 注意：这个函数没有返回值，而是改变了instance的属性的值
        self.__score = score

# %%
bart = Student('Bart Simpson', 59)

# %%
bart.get_score()
# Out:
# 59

# %%
bart.set_score(99)

# %%
bart.get_score()
# Out:
# 99

# %%
bart.score = 93

# %% [markdown]
# 你也许会问，原先那种直接通过bart.score = 99也可以修改啊，为什么要定义一个方法大费周折？因为在方法中，可以对参数做检查，避免传入无效的参数：

# %%
class Student(object):

    def __init__(self, name, score):
        self.__name = name
        self.__score = score
    
    def __str__(self):
        return 'name: %s\nscore: %s'%(self.__name, self.__score)
    
    def print_score(self):
        print('%s: %s' % (self.__name, self.__score))
    
    def get_name(self):
        return self.__name
    def get_score(self):
        return self.__score
    def set_score(self,score):
        if 0<=score<=100:
            self.__score = score
        else:
            raise ValueError('bad score')

# %%
bart = Student('Bart Simpson', 99)

# %%
bart.set_score(120)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-2043a071494c> in <module>
# ----> 1 bart.set_score(120)
#
# <ipython-input-63-b91f610a47c6> in set_score(self, score)
#      19             self.__score = score
#      20         else:
# ---> 21             raise ValueError('bad score')
#
# ValueError: bad score

# %% [markdown]
# 最后注意下面的这种错误写法：

# %%
bart = Student('Bart Simpson', 59)
bart.get_name()
bart.__name = 'New Name' # 设置__name变量！
bart.__name
'New Name'
# Out:
# 'New Name'

# %% [markdown]
# 表面上看，外部代码“成功”地设置了\_\_name变量，但实际上这个\_\_name变量和class内部的\_\_name变量不是一个变量！内部的\_\_name变量已经被Python解释器自动改成了_Student\_\_name，而外部代码给bart新增了一个\_\_name变量。不信试试：

# %%
bart.get_name()
# Out:
# 'Bart Simpson'

# %% [markdown]
# 双下划线开头的实例变量是不是一定不能从外部访问呢？其实也不是。不能直接访问\_\_name是因为Python解释器对外把\_\_name变量改成了_Student\_\_name，所以，仍然可以通过_Student\_\_name来访问\_\_name变量：

# %%
bart._Student__name
# Out:
# 'Bart Simpson'

# %%
bart._Student__name = 'bart'

# %%
print(bart)
# Out:
# name: bart
# score: 59

# %% [markdown]
# 总的来说就是，Python本身没有任何机制阻止你干坏事。

# %% [markdown]
# ## 第三节 继承和多态

# %% [markdown]
# 在OOP程序设计中，当我们定义一个class的时候，可以从某个现有的class继承，新的class称为子类（Subclass），而被继承的class称为基类、父类或超类（Base class、Super class）。

# %% [markdown]
# 继承可以把父类的所有功能都直接拿过来，这样就不必从零做起，子类只需要新增自己特有的方法，也可以把父类不适合的方法覆盖重写。

# %% [markdown]
# 比如，我们已经编写了一个名为Animal的class，有一个run()方法可以直接打印：

# %%
class Animal(object):
    def run(self):
        print('Animal is running...')

# %% [markdown]
# 当我们需要编写Dog和Cat类时，就可以直接从Animal类继承：

# %%
class Dog(Animal):   #Dog类从Animal继承，Dog与Cat是Animal的子类
    pass

class Cat(Animal):
    pass

# %% [markdown]
# 对于Dog来说，Animal就是它的父类，对于Animal来说，Dog就是它的子类。Cat和Dog类似。
#
# 继承有什么好处？最大的好处是子类获得了父类的全部功能。由于Animial实现了run()方法，因此，Dog和Cat作为它的子类，什么事也没干，就自动拥有了run()方法：

# %%
dog = Dog() #建立dog实例，不需要传参数
dog.run() #调用dog.run的函数

cat = Cat()
cat.run()
# Out:
# Animal is running...
# Animal is running...

# %% [markdown]
# 当然，也可以对子类增加一些方法，比如Dog类：

# %%
class Dog(Animal):

    def eat(self):
        print('Eating meat...')

# %%
dog = Dog()
dog.run()
dog.eat()
# Out:
# Animal is running...
# Eating meat...

# %% [markdown]
# 继承的第二个好处需要我们对代码做一点改进。你看到了，无论是Dog还是Cat，它们run()的时候，显示的都是Animal is running...，符合逻辑的做法是分别显示Dog is running...和Cat is running...，因此，对Dog和Cat类改进如下：

# %%
class Dog(Animal):

    def run(self):
        print('Dog is running...')

class Cat(Animal):

    def run(self):
        print('Cat is running...')

# %%
dog = Dog()
dog.run()

cat = Cat()
cat.run()
# Out:
# Dog is running...
# Cat is running...

# %% [markdown]
# **多态**

# %% [markdown]
# 要理解什么是多态，我们首先要对数据类型再作一点说明。当我们定义一个class的时候，我们实际上就定义了一种数据类型。我们定义的数据类型和Python自带的数据类型，比如str、list、dict没什么两样：

# %%
a = list() # a是list类型
b = Animal() # b是Animal类型
c = Dog() # c是Dog类型

# %%
isinstance(a, list) #询问a是list类型
isinstance(b, Animal)
isinstance(c, Dog)
# Out:
# True

# %%
isinstance(c, Animal)
# Out:
# True

# %%
b = Animal()
isinstance(b, Dog)
False
# Out:
# False

# %% [markdown]
# 要理解多态的好处，我们还需要再编写一个函数，这个函数接受一个Animal类型的变量：

# %%
def run_twice(animal):
    animal.run()
    animal.run()

# %% [markdown]
# 当我们传入Animal的实例时，run_twice()就打印出：

# %%
run_twice(Animal())
# Out:
# Animal is running...
# Animal is running...

# %%
run_twice(Dog())
# Out:
# Dog is running...
# Dog is running...

# %%
run_twice(Cat())
# Out:
# Cat is running...
# Cat is running...

# %%
class Tortoise(Animal):
    def run(self):
        print('Tortoise is running slowly...')

# %%
 run_twice(Tortoise())
# Out:
# Tortoise is running slowly...
# Tortoise is running slowly...

# %% [markdown]
# 你会发现，新增一个Animal的子类，不必对run_twice()做任何修改，实际上，任何依赖Animal作为参数的函数或者方法都可以不加修改地正常运行，原因就在于多态。
#
# 多态的好处就是，当我们需要传入Dog、Cat、Tortoise……时，我们只需要接收Animal类型就可以了，因为Dog、Cat、Tortoise……都是Animal类型，然后，按照Animal类型进行操作即可。由于Animal类型有run()方法，因此，传入的任意类型，只要是Animal类或者子类，就会自动调用实际类型的run()方法，这就是多态的意思：
#
# 对于一个变量，我们只需要知道它是Animal类型，无需确切地知道它的子类型，就可以放心地调用run()方法，而具体调用的run()方法是作用在Animal、Dog、Cat还是Tortoise对象上，由运行时该对象的确切类型决定，这就是多态真正的威力：调用方只管调用，不管细节，而当我们新增一种Animal的子类时，只要确保run()方法编写正确，不用管原来的代码是如何调用的。
#
# 甚至于，连Animal的子类都不用，只要它有一个run方法就行！！！
#
# 这就是著名的“开闭”原则：
#
# - 对扩展开放：允许新增Animal子类；允许“类似”Animal类
#
# - 对修改封闭：不需要修改依赖Animal类型的run_twice()等函数。

# %%
class car():
    def run(self):
        print('Car is running very fast!!!')

# %%
class Bmw(car):
    def run(self):
        print('Bmw is running very fast!!!')

# %%
bmw = Bmw()

# %%
 run_twice(bmw)
# Out:
# Bmw is running very fast!!!
# Bmw is running very fast!!!

# %% [markdown]
# ## 第四节 获取对象信息

# %% [markdown]
# 当我们拿到一个对象的引用时，如何知道这个对象是什么类型、有哪些方法呢？
#
# - type()
# - isinstance()
# - dir()
# - getattr()
# - setattr()
# - hasattr()

# %%
type(123),type('abc'),type(None),type(abs),type(bart)
# Out:
# (int, str, NoneType, builtin_function_or_method, __main__.Student)

# %% [markdown]
# type()函数返回的是什么类型呢？它返回对应的Class类型

# %%
type(123) == int
# Out:
# True

# %%
type('abc') == str
# Out:
# True

# %%
a = Animal()
d = Dog()

# %%
class Husky(Dog):
    pass

# %%
h = Husky()

# %% [markdown]
# object -> Animal -> Dog -> Husky

# %%
type(h)
# Out:
# __main__.Husky

# %%
isinstance(h,Husky),isinstance(h,Dog),isinstance(h,Animal),isinstance(h,object)
# Out:
# (True, True, True, True)

# %%
isinstance(d,Husky),isinstance(d,Dog),isinstance(d,Animal),isinstance(d,object)
# Out:
# (False, True, True, True)

# %% [markdown]
# 并且还可以判断一个变量是否是某些类型中的一种，比如下面的代码就可以判断是否是list或者tuple：

# %%
isinstance([1, 2, 3], (list, tuple))
# Out:
# True

# %%
isinstance((1, 2, 3), (list, tuple))
# Out:
# True

# %%
isinstance((1), (list, tuple))
# Out:
# False

# %% [markdown]
# dir()返回一个对象的所有属性和方法

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
dir('ABC')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
dir(h)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'run']

# %%
'ABC'.find('B')
# Out:
# 1

# %% [markdown]
# 类似\_\_ xxx\_\_的属性和方法在Python中都是有特殊用途的，比如\_\_len\_\_方法返回长度。
# 在Python中，如果你调用len()函数试图获取一个对象的长度，实际上，在len()函数内部，
# 它自动去调用该对象的\_\_ len\_\_()方法，
# 所以，下面的代码是等价的：

# %%
 len('ABC'), 'ABC'.__len__()
# Out:
# (3, 3)

# %% [markdown]
# 仅仅把属性和方法列出来是不够的，配合getattr()、setattr()以及hasattr()，我们可以直接操作一个对象的状态：

# %%
class MyObject(object):
     def __init__(self):
         self.x = 9
     def power(self):
         return self.x * self.x

# %%
obj = MyObject()

# %%
hasattr(obj, 'x') # 询问有属性'x'吗？
# Out:
# True

# %%
obj.x
# Out:
# 9

# %%
hasattr(obj, 'power')
# Out:
# True

# %%
hasattr(MyObject, 'power')
# Out:
# True

# %%
hasattr(MyObject, 'x')
# Out:
# False

# %% [markdown]
# 如果试图获取不存在的属性，会抛出AttributeError的错误：
#
# 可以传入一个default参数，如果属性不存在，就返回默认值：

# %%
getattr(obj, 'z')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-95c3c0ec4e01> in <module>
# ----> 1 getattr(obj, 'z')
#
# AttributeError: 'MyObject' object has no attribute 'z'

# %%
getattr(obj, 'z',404)
# Out:
# 404

# %% [markdown]
# ## 第五节 实例属性和类属性

# %% [markdown]
# 由于Python是动态语言，根据类创建的实例可以任意绑定属性。
#
# 给实例绑定属性的方法是通过实例变量，或者通过self变量：

# %%
class Student(object):
    def __init__(self, name):
        self.name = name

s = Student('Bob')
s.score = 90

# %% [markdown]
# 但是，如果`Student`类本身需要绑定一个属性呢？可以直接在class中定义属性，这种属性是类属性，归Student类所有：

# %%
class Student(object):
    name = 'Student'

# %%
s = Student()

# %%
s.name,Student.name ## 当我们定义了一个类属性后，这个属性虽然归类所有，但类的所有实例都可以访问到。来测试一下：
# Out:
# ('Student', 'Student')

# %%
s.name='micheal'

# %%
s.name,Student.name
# Out:
# ('micheal', 'Student')

# %%
del s.name

# %%
s.name
# Out:
# 'Student'

# %% [markdown]
# 从上面的例子可以看出，在编写程序的时候，千万不要对实例属性和类属性使用相同的名字，因为相同名称的实例属性将屏蔽掉类属性，但是当你删除实例属性后，再使用相同的名称，访问到的将是类属性。

# %%
class Student(object):
    count = 0

    def __init__(self, name):
        self.name = name
        Student.count += 1

# %%
if Student.count != 0:
    print('测试失败!')
else:
    bart = Student('Bart')
    if Student.count != 1:
        print('测试失败!')
    else:
        lisa = Student('Bart')
        if Student.count != 2:
            print('测试失败!')
        else:
            print('Students:', Student.count)
            print('测试通过!')
# Out:
# Students: 2
# 测试通过!

# %%
x2 = Student('b')

# %%
x2.count
# Out:
# 3

# %%
Student.count
# Out:
# 3

# %%
x3  = Student('b')

# %% [markdown]
# 实例属性属于各个实例所有，互不干扰；
#
# 类属性属于类所有，所有实例共享一个属性；
#
# 不要对实例属性和类属性使用相同的名字，否则将产生难以发现的错误。

# %% [markdown]
# ## 第六节 面向对象高级编程

# %% [markdown]
# - \_\_slots\_\_
# - 多重继承

# %% [markdown]
# 如果我们想要限制实例的属性怎么办？比如，只允许对Student实例添加name和age属性。
#
# 为了达到限制的目的，Python允许在定义class的时候，定义一个特殊的\_\_slots\_\_变量，来限制该class实例能添加的属性：

# %%
class Student(object):
    __slots__ = ('name', 'age') # 用tuple定义允许绑定的属性名称

# %%
s = Student() 
s.name = 'Michael'
s.age = 25

# %%
s.score = 99
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-43bad5f5e779> in <module>
# ----> 1 s.score = 99
#
# AttributeError: 'Student' object has no attribute 'score'

# %% [markdown]
# 由于'score'没有被放到__slots__中，所以不能绑定score属性，试图绑定score将得到AttributeError的错误。
#
# 使用__slots__要注意，__slots__定义的属性仅对当前类实例起作用，对继承的子类是不起作用的：

# %%
class GraduateStudent(Student):
    pass

g = GraduateStudent()
g.score = 9999

# %% [markdown]
# **多重继承**
# 继承多个父类

# %%
class Runnable(object):
    def run(self):
        print('Running...')

class Flyable(object):
    def fly(self):
        print('Flying...')

# %%
class Animal(object):
    pass

# 大类:
class Mammal(Animal):
    pass

class Bird(Animal):
    pass

# 各种动物:
class Dog(Mammal):
    pass

class Bat(Mammal):
    pass

class Parrot(Bird):
    pass

class Ostrich(Bird):
    pass

# %% [markdown]
# 对于需要Runnable功能的动物，就多继承一个Runnable，例如Dog：

# %%
class Dog(Mammal, Runnable): 
    pass

# %% [markdown]
# 对于需要Flyable功能的动物，就多继承一个Flyable，例如Bat：

# %%
class Bat(Mammal, Flyable):
    pass

# %% [markdown]
# ## 作业

# %% [markdown]
# 使用面向对象编程方法，编写一个斗地主游戏。
# 要求：
# - 设计简单策略，计算机可以自动完成斗地主游戏，相当于游戏中的“托管”
# - 从输出结果，可以很容易地看出斗地主的过程。
# - 参考框架
#
# 需要三个玩家

# %%
#作业框架
class DouDz():
    def __init__(self, game_over = False, dz=None,farmer1=None,farmer2=None):
        self.game_over = game_over
        self.dz = dz
        self.farmer1 = farmer1
        self.farmer2 = farmer2
    def shuffle(self): #定义洗盘
        pass
    def start(self):
        pass
    def play(self,player,cards1,cards2):
        pass

game = DouDz()
game.shuffle() ## 可能需要一些特殊的包来完成,54张牌百度搬运代码
game.start()

cards0 = None
cards1 = None
cards2 = None
while not game.game_over:
    cards0 = game.play('dz',cards1,cards2)
    cards1 = game.play('farmer1',cards0,cards2)
    cards2 = game.play('farmer2',cards0,cards1)

# %% [markdown]
# 第三次课 Python科学计算模块
# 时间：9月20日 周五10-12节（18:40-21:30）

# %% [markdown]
# ## 第三章  Python科学计算模块

# %% [markdown]
# 本部分主要介绍Python中的科学计算模块：Numpy与Scipy的使用。现代科学都是建立在科学计算的发展基础之上。所以，如何存储数据，然后可以进行各种运算（例如：三角函数运算，指数运算，更高级别的代数运算等）也是数据科学的基础。

# %% [markdown]
# ## 第一节 Numpy 模块简介

# %% [markdown]
# NumPy（Numerical Python的简称）是Python数值计算最重要的基础包。大多数提供科学计算的包都是用NumPy的数组作为构建基础。
#
# NumPy的部分功能如下：
#
#     ndarray（x=0-10,d=dimension,多维数组），一个具有矢量算术运算和复杂广播能力的快速且节省空间的多维数组。
#     用于对整组数据进行快速运算的标准数学函数（无需编写循环）。
#     用于读写磁盘数据的工具以及用于操作内存映射文件的工具。
#     线性代数、随机数生成以及傅里叶变换功能。
#     用于集成由C、C++、Fortran等语言编写的代码的A C API。
#
# 由于NumPy提供了一个简单易用的C API，因此很容易将数据传递给由低级语言编写的外部库，外部库也能以NumPy数组的形式将数据返回给Python。这个功能使Python成为一种包装C/C++/Fortran历史代码库的选择，并使被包装库拥有一个动态的、易用的接口。
#
# NumPy本身并没有提供多么高级的数据分析功能，理解NumPy数组以及面向数组的计算将有助于你更加高效地使用诸如pandas之类的工具。
#
# 对于大部分数据分析应用而言，我最关注的功能主要集中在：
#
#     用于数据整理和清理、子集构造和过滤、转换等快速的矢量化数组运算。
#     常用的数组算法，如排序、唯一化、集合运算等。
#     高效的描述统计和数据聚合/摘要运算。
#     用于异构数据集的合并/连接运算的数据对齐和关系型数据运算。
#     将条件逻辑表述为数组表达式（而不是带有if-elif-else分支的循环）。
#     数据的分组运算（聚合、转换、函数应用等）。。
#
# 虽然NumPy提供了通用的数值数据处理的计算基础，但大多数读者可能还是想将pandas作为统计和分析工作的基础，尤其是处理表格数据时。pandas还提供了一些NumPy所没有的领域特定的功能，如时间序列处理等。
#
# NumPy之于数值计算特别重要的原因之一，是因为它可以高效处理大数组的数据。这是因为：
#
#     NumPy是在一个连续的内存块中存储数据，独立于其他Python内置对象。NumPy的C语言编写的算法库可以操作内存，而不必进行类型检查或其它前期工作。比起Python的内置序列，NumPy数组使用的内存更少。
#     NumPy可以在整个数组上执行复杂的计算，而不需要Python的for循环。
#
# 要搞明白具体的性能差距，考察一个包含一百万整数的数组，和一个等价的Python列表：

# %%
import numpy as np

my_arr = np.arange(1000000)
my_list = list(range(1000000))

# %% [markdown]
# 对列表做一个平方？
# x = [1,2,3,4,5,6]里面做平方 ？？

# %%
# %time for _ in range(10): my_arr2 = my_arr * 2
# Out:
# CPU times: user 12.7 ms, sys: 5.65 ms, total: 18.4 ms
# Wall time: 18.8 ms

# %%
# %time for _ in range(10): my_list2 = [x * 2 for x in my_list]
# Out:
# CPU times: user 658 ms, sys: 182 ms, total: 840 ms
# Wall time: 840 ms

# %% [markdown]
# ## 第一节 NumPy的ndarray：一种多维数组对象

# %%
import as

# %% [markdown]
# ## 第二节 通用函数：快速的元素级数组函数

# %% [markdown]
# ## 第三节 利用数组进行数据处理

# %% [markdown]
# ## 第四节 用于数组的文件输入输出

# %% [markdown]
# ## 第五节 线性代数

# %% [markdown]
# ## 第六节 随机数生成

# %% [markdown]
# ## 第七节 Scipy 模块简介

# %% [markdown]
# SciPy是基于NumPy开发的高级模块，它提供了许多数学算法和函数的实现，用于解决科学计算中的一些标准问题。例如数值积分和微分方程求解，扩展的矩阵计算，最优化，概率分布和统计函数，甚至包括信号处理等。
#
# 作为标准科学计算程序库，SciPy类似于Matlab的工具箱，它是Python科学计算程序的核心包，它用于有效地计算NumPy矩阵，与NumPy矩阵协同工作。

# %% [markdown]
# - 线性代数
# - 最优化
# - 插值
# - 统计

# %% [markdown]
# **作业**：实现Collaberative Filtering。并用该程序对10000Lens数据做分析。

# %% [markdown]
# 第四次课 Python 数据分析模块
# 时间：9月25日 周三10-12节（18:40-21:30）

# %% [markdown]
# 第五次课 文本处理模块
# 时间：9月27日 周五10-12节（18:40-21:30）

# %% [markdown]
# 第六次课 【停课】
# 时间：10月2日 周三10-12节（18:40-21:30） 【停课】

# %% [markdown]
# 第六次课 【停课】
# 时间：10月4日 周五10-12节（18:40-21:30） 【停课】

# %% [markdown]
# 第六次课  Python绘图模块
# 时间：10月9日 周三10-12节（18:40-21:30）

# %% [markdown]
# 第七次课 Python爬虫模块
# 时间：10月11日 周五10-12节（18:40-21:30）

# %% [markdown]
# 第八次课 Python 统计与机器学习模块
# 时间：10月16日 周三10-12节（18:40-21:30）

# %% [markdown]
# 九次课 考试
# 时间：10月18日 周五10-12节（18:40-21:30） 【第六周最后一次课】
