# %% [markdown]
# 1.用python写出一个数学竖式。
#
# 用键盘输入三个量：第一个数字、第二个数字、+或-号
#
# 输出：一个漂亮的数学竖式，如下图所示。

# %%
z = 0
a = int(input("请输入第一个整数："))  #键盘的输入，形式是否对齐
b = int(input("请输入第二个整数："))
m = input("请输入运算符（+ 或 -）：")

maxlen = max(len(str(a)),len(str(b)))
line = '-' * (maxlen+3)

if m == "+":
    z = a+b
elif m == '-':
    z = a-b
if m == '+' or m == '-':
    print("{:>{}}".format(a,maxlen+2)) #需要对齐 a为第一个数，后面为长度{}表示长度
    print(m,"{:>{}}".format(b,maxlen))
    print(line)
    print("{:>{}}".format(z,maxlen+2))
else:
    print ("输入运算符有误")
# Out:
# 请输入第一个整数：121343512
# 请输入第二个整数：24135
# 请输入运算符（+ 或 -）：-
#   121343512
# -     24135
# ------------
#   121319377

# %% [markdown]
# 2.用python编写24点小游戏。
#
# 要求：从键盘输入4个数字，每个在1-10（包含）之间
#
# 判断是否可以用 +-\*/ 通过运算得到结果24，并输出运算过程
#
# 结果越简洁越好

# %%
import itertools

ops = '+-*/'
patterns = [
    "( %d %s %d ) %s ( %d %s %d )", # (a+b) * (c-d)
    "( ( %d %s %d ) %s %d ) %s %d", # ((a+b)*c) - d
    "( %d %s ( %d %s %d ) ) %s %d", # (a-(b-c)) * d
    "%d %s ( ( %d %s %d ) %s %d )", 
    "%d %s ( %d %s ( %d %s %d ) )" 
    
    
]
#采用枚举的方法，（ab）（cd）;（（ab）c）d; a(bc)d


def fun(cards):
    find = False
    for item in itertools.permutations(cards): 
        for p in patterns:
            ans = [p % (item[0],o1,item[1],o2,item[2],o3,item[3]) for o1 in ops for o2 in ops for o3 in ops]
            for a in ans:
                try:
                    if eval(a) == 24  :
                        print (a + " = 24\n")
                        find = True
                except ZeroDivisionError:
                    continue
    if find == False:
        print ('not find!')

cards = input("请输入4个数字（1到10之间，空格隔开）：")
fun([int(s) for s in cards.split()])


### 进一步提升，如何去重，参考：https://www.jianshu.com/p/716687780dd5; eval函数把字符串转换为，需要考虑重复，如何去掉重复的。
# Out:
# 请输入4个数字（1到10之间，空格隔开）：2 4 5 6
# ( ( 2 + 4 ) * 5 ) - 6 = 24
#
# ( 2 * ( 4 + 5 ) ) + 6 = 24
#
# ( 2 * ( 5 + 4 ) ) + 6 = 24
#
# ( ( 4 + 2 ) * 5 ) - 6 = 24
#
# 4 - ( ( 2 - 6 ) * 5 ) = 24
#
# ( 4 * 5 ) - ( 2 - 6 ) = 24
#
# ( ( 4 + 5 ) * 2 ) + 6 = 24
#
# ( ( 4 * 5 ) - 2 ) + 6 = 24
#
# 4 - ( 5 * ( 2 - 6 ) ) = 24
#
# ( 4 * 5 ) + ( 6 - 2 ) = 24
#
# ( ( 4 * 5 ) + 6 ) - 2 = 24
#
# 4 + ( 5 * ( 6 - 2 ) ) = 24
#
# 4 + ( ( 6 - 2 ) * 5 ) = 24
#
# ( 5 * ( 2 + 4 ) ) - 6 = 24
#
# ( 5 * 4 ) - ( 2 - 6 ) = 24
#
# ( ( 5 + 4 ) * 2 ) + 6 = 24
#
# ( ( 5 * 4 ) - 2 ) + 6 = 24
#
# ( 5 * ( 4 + 2 ) ) - 6 = 24
#
# ( 5 * 4 ) + ( 6 - 2 ) = 24
#
# ( ( 5 * 4 ) + 6 ) - 2 = 24
#
# ( 5 * 6 ) - ( 2 + 4 ) = 24
#
# ( ( 5 * 6 ) - 2 ) - 4 = 24
#
# ( 5 * ( 6 - 2 ) ) + 4 = 24
#
# ( 5 * 6 ) - ( 4 + 2 ) = 24
#
# ( ( 5 * 6 ) - 4 ) - 2 = 24
#
# ( 6 - 2 ) + ( 4 * 5 ) = 24
#
# 6 + ( 2 * ( 4 + 5 ) ) = 24
#
# 6 - ( 2 - ( 4 * 5 ) ) = 24
#
# ( 6 - 2 ) + ( 5 * 4 ) = 24
#
# ( ( 6 - 2 ) * 5 ) + 4 = 24
#
# 6 + ( 2 * ( 5 + 4 ) ) = 24
#
# 6 - ( 2 - ( 5 * 4 ) ) = 24
#
# ( 6 + ( 4 * 5 ) ) - 2 = 24
#
# 6 + ( ( 4 + 5 ) * 2 ) = 24
#
# 6 + ( ( 4 * 5 ) - 2 ) = 24
#
# ( 6 * 5 ) - ( 2 + 4 ) = 24
#
# ( ( 6 * 5 ) - 2 ) - 4 = 24
#
# ( 6 * 5 ) - ( 4 + 2 ) = 24
#
# ( ( 6 * 5 ) - 4 ) - 2 = 24
#
# ( 6 + ( 5 * 4 ) ) - 2 = 24
#
# 6 + ( ( 5 + 4 ) * 2 ) = 24
#
# 6 + ( ( 5 * 4 ) - 2 ) = 24

# %% [markdown]
# 3.对附件的英文小说: pride_and_prejudice.txt
#
# 统计出其中使用的单词数量，
#
# 并计算每一个单词的出现次数。
#
# Report最多的10个单词。

# %%
prejudiceTxt = open('pride_and_prejudice.txt','r').read()
#replace punctuation
for i in "~!@#$%^&*()_+-=:<>?{}[]|\\/\'\'\",.":
        prejudiceTxt = prejudiceTxt.replace(i,' ')

Words = prejudiceTxt.split(' ')
wordcount = {}
for iword in Words:
    if not iword:
        continue
    #if iword not in wordcount:  
    #    wordcount[iword] = 1 不在里面等于1
    #else: 
    #    wordcount[iword] +=1 在里面+1. 还可以掉一个计算词频的包。
    wordcount[iword]=wordcount.get(iword,0)+1

worditerms = list(wordcount.items())
worditerms.sort(key=lambda x:x[1], reverse=True)
for i in range(10):
    word,count = worditerms[i]
    print('{0:<12}{1}'.format(word,count))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-13c950b23e16> in <module>
# ----> 1 prejudiceTxt = open('pride_and_prejudice.txt','r').read()
#       2 #replace punctuation
#       3 for i in "~!@#$%^&*()_+-=:<>?{}[]|\\/\'\'\",.":
#       4         prejudiceTxt = prejudiceTxt.replace(i,' ')
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pride_and_prejudice.txt'

# %% [markdown]
# 4.找出10000以内的所有孪生素数对。

# %%
from math import sqrt 
count = 0

def findprimetwin(number):

    for i in range(2, number + 1): 
        if isprime(i):
            if isprime(i + 2): #判断i + 2是否同时是素数
                print((i, i + 2)) #打印素数
                global count
                count += 1
            i += 2

def isprime(num):

    flag = True
    for i in range(2, int(sqrt(num)) + 1):  #看是否能被整除
        if num % i == 0:
            flag = False
    return flag

print('10000以内共有孪生素数对具体如下：')
findprimetwin(10000)
print('共有',count,'对')
# Out:
# 10000以内共有孪生素数对具体如下：
# (3, 5)
# (5, 7)
# (11, 13)
# (17, 19)
# (29, 31)
# (41, 43)
# (59, 61)
# (71, 73)
# (101, 103)
# (107, 109)
# (137, 139)
# (149, 151)
# (179, 181)
# (191, 193)
# (197, 199)
# (227, 229)
# (239, 241)
# (269, 271)
# (281, 283)
# (311, 313)
# (347, 349)
# (419, 421)
# (431, 433)
# (461, 463)
# (521, 523)
# (569, 571)
# (599, 601)
# (617, 619)
# (641, 643)
# (659, 661)
# (809, 811)
# (821, 823)
# (827, 829)
# (857, 859)
# (881, 883)
# (1019, 1021)
# (1031, 1033)
# (1049, 1051)
# (1061, 1063)
# (1091, 1093)
# (1151, 1153)
# (1229, 1231)
# (1277, 1279)
# (1289, 1291)
# (1301, 1303)
# (1319, 1321)
# (1427, 1429)
# (1451, 1453)
# (1481, 1483)
# (1487, 1489)
# (1607, 1609)
# (1619, 1621)
# (1667, 1669)
# (1697, 1699)
# (1721, 1723)
# (1787, 1789)
# (1871, 1873)
# (1877, 1879)
# (1931, 1933)
# (1949, 1951)
# (1997, 1999)
# (2027, 2029)
# (2081, 2083)
# (2087, 2089)
# (2111, 2113)
# (2129, 2131)
# (2141, 2143)
# (2237, 2239)
# (2267, 2269)
# (2309, 2311)
# (2339, 2341)
# (2381, 2383)
# (2549, 2551)
# (2591, 2593)
# (2657, 2659)
# (2687, 2689)
# (2711, 2713)
# (2729, 2731)
# (2789, 2791)
# (2801, 2803)
# (2969, 2971)
# (2999, 3001)
# (3119, 3121)
# (3167, 3169)
# (3251, 3253)
# (3257, 3259)
# (3299, 3301)
# (3329, 3331)
# (3359, 3361)
# (3371, 3373)
# (3389, 3391)
# (3461, 3463)
# (3467, 3469)
# (3527, 3529)
# (3539, 3541)
# (3557, 3559)
# (3581, 3583)
# (3671, 3673)
# (3767, 3769)
# (3821, 3823)
# (3851, 3853)
# (3917, 3919)
# (3929, 3931)
# (4001, 4003)
# (4019, 4021)
# (4049, 4051)
# (4091, 4093)
# (4127, 4129)
# (4157, 4159)
# (4217, 4219)
# (4229, 4231)
# (4241, 4243)
# (4259, 4261)
# (4271, 4273)
# (4337, 4339)
# (4421, 4423)
# (4481, 4483)
# (4517, 4519)
# (4547, 4549)
# (4637, 4639)
# (4649, 4651)
# (4721, 4723)
# (4787, 4789)
# (4799, 4801)
# (4931, 4933)
# (4967, 4969)
# (5009, 5011)
# (5021, 5023)
# (5099, 5101)
# (5231, 5233)
# (5279, 5281)
# (5417, 5419)
# (5441, 5443)
# (5477, 5479)
# (5501, 5503)
# (5519, 5521)
# (5639, 5641)
# (5651, 5653)
# (5657, 5659)
# (5741, 5743)
# (5849, 5851)
# (5867, 5869)
# (5879, 5881)
# (6089, 6091)
# (6131, 6133)
# (6197, 6199)
# (6269, 6271)
# (6299, 6301)
# (6359, 6361)
# (6449, 6451)
# (6551, 6553)
# (6569, 6571)
# (6659, 6661)
# (6689, 6691)
# (6701, 6703)
# (6761, 6763)
# (6779, 6781)
# (6791, 6793)
# (6827, 6829)
# (6869, 6871)
# (6947, 6949)
# (6959, 6961)
# (7127, 7129)
# (7211, 7213)
# (7307, 7309)
# (7331, 7333)
# (7349, 7351)
# (7457, 7459)
# (7487, 7489)
# (7547, 7549)
# (7559, 7561)
# (7589, 7591)
# (7757, 7759)
# (7877, 7879)
# (7949, 7951)
# (8009, 8011)
# (8087, 8089)
# (8219, 8221)
# (8231, 8233)
# (8291, 8293)
# (8387, 8389)
# (8429, 8431)
# (8537, 8539)
# (8597, 8599)
# (8627, 8629)
# (8819, 8821)
# (8837, 8839)
# (8861, 8863)
# (8969, 8971)
# (8999, 9001)
# (9011, 9013)
# (9041, 9043)
# (9239, 9241)
# (9281, 9283)
# (9341, 9343)
# (9419, 9421)
# (9431, 9433)
# (9437, 9439)
# (9461, 9463)
# (9629, 9631)
# (9677, 9679)
# (9719, 9721)
# (9767, 9769)
# (9857, 9859)
# (9929, 9931)
# 共有 205 对

# %% [markdown]
# 5.针对附件的曲线数据(sample.txt)，画出曲线图。

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import struct

lines = []
with open('sample.txt', 'r', encoding='utf-8') as csvf:  #需用utf-8编码
    k = 0
    for line in csv.reader(csvf):
        k = k + 1
        lines.append(line[0].split('\t'))
        #print(line)

for i in range(int(len(lines)/2)):  #画出所有的图
    plt.rcParams['figure.figsize'] = (8.0, 6.0)
    codes1 = lines[2*i][5]
    codes2 = lines[2*i+1][5]
    x = []
    y = []
        for j in range(int((len(codes1)-2)/8)):
        hexcode1 = codes1[8*j+2:8*j+10]
        bts1 = bytes.fromhex(hexcode1)
        a = struct.unpack('<f',bts1)[0]
        x.append(a)
        hexcode2 = codes2[8*j+2:8*j+10]
        bts2 = bytes.fromhex(hexcode2)
        b = struct.unpack('<f',bts2)[0]
        y.append(b)
    plt.plot(x,y)
plt.show()
# Out:
#   File "<ipython-input-8-2cf7af736a24>", line 20
#     for j in range(int((len(codes1)-2)/8)):
#     ^
# IndentationError: unexpected indent

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import struct

lines = []
with open('sample.txt', 'r', encoding='utf-8') as csvf:  #需用utf-8编码
    k = 0
    for line in csv.reader(csvf):
        k = k + 1
        lines.append(line[0].split('\t'))

for i in range(int(len(lines)/2)):  #画出所有的图
    plt.rcParams['figure.figsize'] = (8.0, 6.0)
    codes1 = lines[2*i][5]
    codes2 = lines[2*i+1][5]
    x = []
    y = []
    for j in range(int((len(codes1)-2)/8)):
        hexcode1 = codes1[8*j+2:8*j+10]
        bts1 = bytes.fromhex(hexcode1)
        a = struct.unpack('<f',bts1)[0]
        x.append(a)
        hexcode2 = codes2[8*j+2:8*j+10]
        bts2 = bytes.fromhex(hexcode2)
        b = struct.unpack('<f',bts2)[0]
        y.append(b)
    plt.plot(x,y)
plt.show()
